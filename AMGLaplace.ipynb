# %%
import numpy as np
import matplotlib.pyplot as plt
import time
pi = np.pi

# %% [markdown]
# # Algebraic two grid method for Laplace equation on a square
#
# The structure of the equation $\nabla^2 u(x) = 0$ on the grid is
#
# $$\begin{pmatrix}
# T & I & 0 & 0 & 0 & \cdots & 0 & 0 & 0\\
# I & T & I & 0 & 0 & \cdots & 0 & 0 & 0 \\
# 0 & I & T & I & 0 & \cdots & 0 & 0 & 0\\
# 0 & 0 & I & T & I & \cdots & 0 & 0 & 0\\
# \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots &\\
# 0 & 0 & 0 & 0 & 0 &  0 & \cdots I & T & I \\
# 0 & 0 & 0 & 0 & 0 & 0 & \cdots 0 & I & T
# \end{pmatrix}\begin{pmatrix}f_{11} \\ f_{12} \\ f_{13} \\ \vdots \\ f_{N1} \\ \vdots \\ f_{NN} \end{pmatrix}=\vec{f},$$
#
# where $T$ is a tridiagonal matrix of dimension $N_x \times N_y$.
#
# $$\begin{pmatrix}
# -4 & 1 & 0 & 0 & \cdots & 0 & 0 & 0\\
# 1 & -4 & 1 & 0 & \cdots & 0 & 0 & 0\\
# 0 & 1 & -4 & 1 & \cdots & 0 & 0 & 0\\
# 0 & 0 & -1 & 4 & \cdots & 0 & 0 & 0\\
# \vdots & \vdots & \vdots & \vdots & \ddots & \vdots & \vdots & \vdots &  \\
# 0 & 0 & 0 & 0 & \cdots & 1 & -4 & 1 \\
# 0 & 0 & 0 & 0 & \cdots & 0 & -4 & 1
# \end{pmatrix}$$
#
# and $I$ the identity matrix of the same dimension. The vector $\vec{f}$ contains the information of the boundary and has the following structure (we write it for $N=4$ for simplicity)
#
# $$\vec{f}=\begin{pmatrix}-u_{01}-u_{10} \\ - u_{02} \\ -u_{03} \\ -u_{04}-u_{15} \\ -u_{20} \\ 0 \\ 0 \\ -u_{25}
# \\-u_{30} \\ 0 \\ 0 \\ -u_{35} \\ - u_{40} - u_{51} \\ -u_{52} \\ -u_{53} \\ -u_{45} - u_{54}
# \end{pmatrix}.$$
#
# The easiest way of solving the problem is by computing $\vec{u} = A^{-1} \vec{f}$
#
# ### Gauss-Seidel method as a smoother
# If we want to solve $A\vec{u}=\vec{f}$ we find the solution iteratively
# $$u_i^{(k+1)}=\frac{1}{a_{ii}}\left(f_i - \sum_{j=i+1}^{n-1} a_{ij}u_j^{(k)} - \sum_{j=0}^{i-1}a_{ij}u_j^{(k+1)} \right) \quad i = 0, 1, \dots ,n-1 $$
# If $i=0$ then we don't consider the last term

# %%
class Laplace:
    #--This class constructs the sets Nl, Sl, SlT and the transfer operators for one grid level--#
    #--it also has an implementation of the two-grid method--#
    def __init__(self,A,f,NVar,eps):
        self.f = f #Boundary conditions
        self.NVar = NVar #Dimension of the matrix A, equal to N*N
        self.A = A
        self.Ni = []
        self.Si = []
        self.SiT = []
        self.eps = eps #Free parameter used to create the strong couplings
        self.wij = 0 #Weights for interpolation
        self.Init = np.random.randint(self.NVar) #Init --> first C-Variable
        #This is the starting point for the coarsening. 
        #It can be random, in the end the result will be some 
        #kind of checkerboard for Laplace's equation. 
        self.UVar = set() #Undecided variables
        for i in range(self.NVar):
            self.UVar.add(i) #In the beginning all the variables are undecided        
        self.FVar = set() #Fine variables
        self.CVar = set() #Coarse variables 
        self.Lambda = np.zeros(self.NVar)
        self.ProlOp = None #Interpolation operator
        self.CoarseOp = None #Coarsening operator
        self.GalerkinOp = None #Galerkin operator
        self.u = np.zeros(self.NVar) #Initial guess for the solution.
        

    def get_Matrix(self):
        return self.A

    def get_UVar(self):
        return self.UVar
    def get_FVar(self):
        return self.FVar
    def get_CVar(self):
        return self.CVar

    def get_Ni(self):
        return self.Ni
    def get_Si(self):
        return self.Si
    def get_SiT(self):
        return self.SiT

    def get_Lambda(self):
        return self.Lambda
    def get_ProlOp(self):
        return self.ProlOp
    
    def NiSiSiT(self):
    #This computes the sets Ni, Si and SiT
    #Epsilon is used to define the strong couplings
        print('NVar',self.NVar) #Total number of variables
        #Ni
        for i in range(self.NVar):
            B = set() #Auxiliary list
            for j in range(self.NVar):
                if j != i and self.A[i,j] != 0:
                    B.add(j)
            self.Ni.append(B)
        #Si
        for i in range(self.NVar):
            B = set()
            for j in range(self.NVar):
                if self.A[i,j] < 0:
                    B.add(abs(self.A[i,j]))
            a_max = max(B)
            B = set()
            for j in range(self.NVar):
                if -self.A[i,j] >= self.eps*a_max and i != j:
                    B.add(j)  
            self.Si.append(B)
        #SiT
        for i in range(self.NVar):
            B = set()
            for j in range(self.NVar):
                if i in self.Si[j]:
                    B.add(j)
            self.SiT.append(B)

    def Lambda_i(self):
        self.Lambda = np.zeros(self.NVar) #We set to zero the values of the U-Variables
        for i in self.UVar:
            self.Lambda[i] = len(self.SiT[i].intersection(self.UVar)) + 2*len(self.SiT[i].intersection(self.FVar))

    def CoarseStep(self):   
        self.CVar.add(self.Init) 
        self.UVar.remove(self.Init)
        for i in self.SiT[self.Init]:
            self.FVar.add(i)
            if i in self.UVar:
                self.UVar.remove(i)
        self.Lambda_i() #We compute Lambda for all the U variables
        maxLamb = max(self.Lambda)
        NewPossibleC = [] #List with new possibe C-Variables
        if maxLamb != 0 and len(self.UVar) != 0: 
            for i in range(len(self.Lambda)):
                if self.Lambda[i] == maxLamb and i in self.UVar:
                    NewPossibleC.append(i)     
            self.Init = NewPossibleC[np.random.randint(len(NewPossibleC))] #Then we repeat the previous steps
        #If the maximum value of Lambda is zero, then there are no more undecided variables.
        else:
            self.Init = -1

    def coarsening(self):   
        while self.Init != -1:     
            self.CoarseStep()

    def Weight(self,i,j):
        #We compute the weight wij, i in F, j in Pi
        Pi = self.CVar.intersection(self.Si[i])
        SumA, SumB = 0, 0
        for k in self.Ni[i]:
            SumA += self.A[i,k]
        for k in Pi:
            SumB += self.A[i,k]
        self.wij = - SumA/SumB * self.A[i,j]/self.A[i,i] 

    def ConstructOperators(self): 
        #We construct the operators by mapping the basis vectors of the coarse grid with the interpolator
        self.ProlOp = np.zeros((self.NVar,len(self.CVar))) #Maps from coarse grid to fine grid
        cont = 0
        for cvar in self.CVar:
            image_vector = np.zeros(self.NVar)
            basis_vector = np.eye(1,self.NVar,cvar)[0] #The entries that correspond to F-variables are set to zero
            #We apply the operator
            for i in range(self.NVar):
                Pi = self.CVar.intersection(self.Si[i]) #Interpolation set
                if i in self.CVar:
                    image_vector[i] = basis_vector[i]
                else:
                    #i in FVar
                    for k in Pi:
                        self.Weight(i,k) #Compute the weight wik
                        image_vector[i] += self.wij*basis_vector[k]
            self.ProlOp[:,cont] = image_vector #We arrange the images in the columns to build the operator
            cont += 1
        self.CoarseOp = np.transpose(self.ProlOp)
        self.GalerkinOp = np.dot(np.dot(self.CoarseOp,self.A),self.ProlOp) 

    def GaussSeidel(self,nu,initial_guess):
        #f has the boundary conditions
        #nu is the number of iterations        
        self.u = initial_guess
        for k in range(nu):
            for i in range(self.NVar):
                SumA = np.dot(self.A[i,i+1:],self.u[i+1:])
                SumB = np.dot(self.A[i,:i],self.u[:i]) 
                self.u[i] = (self.f[i] - SumA - SumB) / self.A[i,i]
        return self.u

    def ExactInv(self):
        #Exact inversion of the matrix
        self.u = np.dot(np.linalg.inv(self.A),self.f)
        return self.u

    def set_up_phase(self):
        self.NiSiSiT() #Construct Ni Si and SiT
        self.coarsening() #Coarse the grid
        self.ConstructOperators() #Construct operators         

    def TwoGridMethod(self,nu1,nu2,initial_guess):
        #nu1 --> pre-smoothing,  nu2 --> post-smoothing
        #We have to call the set up phase outside the function       
        self.u = self.GaussSeidel(nu1,initial_guess) #Pre-smoothing
        errorC = np.dot(np.dot(np.linalg.inv(self.GalerkinOp),self.CoarseOp), self.f-np.dot(self.A,self.u) )
        self.u = self.u + np.dot(self.ProlOp,errorC) #Correction 
        self.u = self.GaussSeidel(nu2,self.u) #Post-smoothing
        return self.u

# %%
class Multigrid:
    def __init__(self,A,NVar,maxl,eps):
        #LEVEL l+1 IS COARSER THAN LEVEL l, i.e. IT HAS LESS VARIABLES
        self.NVar = NVar #Dimension of the matrix A
        self.eps = eps #Parameter used to create the strong couplings
        self.Al = [A] #We store the original matrix and Galerkin operator here
        self.ProlOpl = [] #We store the operators for each level
        #ProlOpl[l] has the operator that takes us from level l+1 to level l
        #Size(ProlOpl) is size(Al)-1
        self.maxl = maxl #Number of grid levels

    def get_Al(self):
        return self.Al
        
    def get_ProlOpl(self):
        return self.ProlOpl
        
    def set_up_phase(self):
        #We create the operators for all the grid levels
        for i in range(self.maxl):
            if  i != maxl-1:
                Nl = self.Al[i].shape[0] #Number of variables at level l
                Syst_l = Laplace(self.Al[i],np.zeros(Nl),Nl,self.eps) #I don't actually need the second argument, but
                #the way my program is written asks me for that thing to work.
                Syst_l.NiSiSiT() #Construct Ni, Si and SiT at the l-level
                Syst_l.coarsening() #Coarse the grid from l-level to l+1 -level
                Syst_l.ConstructOperators() #Construct operators from l-level to l+1 -level
                GalerkinOp = np.dot(
                np.dot( np.transpose(Syst_l.get_ProlOp()), Syst_l.get_Matrix() ), 
                Syst_l.get_ProlOp() ) 
                self.Al.append(GalerkinOp) #Store A at level l+1 
                self.ProlOpl.append(Syst_l.get_ProlOp()) #Store the interpolation operator from l+1 -level to l-level     

    def GaussSeidel(self,nu,fl,ul,level):
        #nu is the number of iterations
        Nl = len(ul)
        for k in range(nu):
            for i in range(Nl):
                SumA = np.dot(self.Al[level][i,i+1:],ul[i+1:])
                SumB = np.dot(self.Al[level][i,:i],ul[:i]) 
                ul[i] = (fl[i] - SumA - SumB) / self.Al[level][i,i]
        return ul

    def V_cycle(self,nu1,nu2,l,fl,ul):
        """
        Multi-grid with V-Cycle
        maxl is the finest level
        nu1: pre-smoothing
        nu2: post-smoothing
        We count l starting from zero
        """    
        if l == self.maxl - 1:
            return np.dot(np.linalg.inv(self.Al[l]),fl) #At this stage we only invert the matrix that's left  
        else:    
            ul = self.GaussSeidel(nu1,fl,ul,l) #Pre-smoothing. We don't want pre smoothing for the
            #exact solution
            fl_1 = np.dot( np.transpose(self.ProlOpl[l]),
                        fl-np.dot(self.Al[l],ul) ) #restriction
            ul_1 = np.zeros(self.Al[l+1].shape[0]) #Vector for the next level. 
            ul_1 = self.V_cycle(nu1,nu2,l+1,fl_1,ul_1)  
    
        ul = ul + np.dot(self.ProlOpl[l],ul_1)
        ul = self.GaussSeidel(nu2,fl,ul,l) #Pre-smoothing  #Post-smoothing
        return ul

# %%
N = 50
#Laplace matrix
A = np.zeros((N*N,N*N))
for i in range(N):
    for j in range(N):
        A[i+j*N,i+j*N] = -4 #Diagonal
for i in range(N-1):
    for j in range(N):            
        A[i+j*N,i+j*N+1] = 1 #Upper diagonal of the triangular submatrices
        A[i+j*N+1,i+j*N] = 1 #Lower diagonal of the triangular submatrices        
for i in range(N):
    for j in range(N-1):
        A[i+j*N  , i+j*N + N] = 1 #Identity upper matrix
        A[i+j*N + N , i+j*N ] = 1 #Identity lower matrix        
A = -A #We do this to be consistent with Stueben notes

#Boundary conditions vector
f = np.zeros(N*N)
L, H, h = 1, 1, 1/(N+1) 
x, y = np.zeros(N), np.zeros(N)
for i in range(N):
    x[i], y[i] = (i+1)*h*L, (i+1)*h*L
#Boundary at x = 0
fx = np.zeros(N) #f_0j
#Boundary at y = 0
fy = np.sin(2*pi*x/L) #fj0
#Boundary at y = H
fH = np.zeros(N) #fj4
#Boundary at x = L 
fL = np.zeros(N) #f4j
for i in range(N):
    f[i+(N-1)*i] = -fy[i] #Bottom boundary (y=0)
    f[i+(N-1)*i+ N-1 ] = -fH[i] #Top boundary (y=H)
for i in range(N):
    f[i] += -fx[i] #Left boundary (x=0)
    f[i+N*(N-1)] += - fL[i] #Right boundary (x=L)
f = -f #Consistency with Stueben notes
def AnalyticSolution(x,y):
    #Here x,y are numbers
    return np.sin(2*pi*x/L)*np.sinh(2*pi*(H-y)/L)/np.sinh(2*pi*H/L)

# %%
#np.random.seed(0)  #We use this seed here to exactly reproduce the two-grid method, but with the V-cycle algorithm
maxl, eps = 4, 0.25
#We measure the setup phase computing time separately
TIME = [] 
nmeas = 10 #We perform ten measurements to determine the computing time. 
for i in range(nmeas):
    start = time.time()
    AMG = Multigrid(A,N*N,maxl,eps) 
    AMG.set_up_phase()
    end = time.time()
    TIME.append(end-start)
TIME = np.array(TIME)
print('Execution time',np.mean(TIME),'+-',np.std(TIME)/np.sqrt(nmeas),'seconds')
# Out:
# NVar 2500
# NVar 1250
# NVar 312
# NVar 2500
# NVar 1250
# NVar 314
# NVar 2500
# NVar 1250
# NVar 312
# NVar 2500
# NVar 1250
# NVar 316
# NVar 2500
# NVar 1250
# NVar 314
# NVar 2500
# NVar 1250
# NVar 313
# NVar 2500
# NVar 1250
# NVar 312
# NVar 2500
# NVar 1250
# NVar 311
# NVar 2500
# NVar 1250
# NVar 313
# NVar 2500
# NVar 1250
# NVar 313
# Execution time 12.853164625167846 +- 0.04106448584789153 seconds

# %%
nu1, nu2, l = 5, 5, 0 #We start at l=0
u0 = np.zeros(N*N)
TIME = [] 
nmeas = 10
for i in range(nmeas):
    start = time.time()
    uAMG = AMG.V_cycle(nu1,nu2,l,f,u0) #We are not taking the set up phase into account
    end = time.time()
    TIME.append(end-start)
TIME = np.array(TIME)
print('Execution time',np.mean(TIME),'+-',np.std(TIME)/np.sqrt(nmeas),'seconds')
# Out:
# Execution time 0.13352444171905517 +- 0.0006774305049765493 seconds

# %%
eps = 0.25
#np.random.seed(0) 
TIME = [] 
nmeas = 10 #We perform ten measurements to determine the computing time. 
for i in range(nmeas):
    start = time.time()
    SystOfEqs = Laplace(A,f,N*N,eps)
    SystOfEqs.set_up_phase()
    end = time.time()
    TIME.append(end-start)
TIME = np.array(TIME)
print('Execution time',np.mean(TIME),'+-',np.std(TIME)/np.sqrt(nmeas),'seconds')
# Out:
# NVar 2500
# NVar 2500
# NVar 2500
# NVar 2500
# NVar 2500
# NVar 2500
# NVar 2500
# NVar 2500
# NVar 2500
# NVar 2500
# Execution time 10.65808618068695 +- 0.027415866411706104 seconds

# %%
TIME = [] 
nmeas = 10
for i in range(nmeas):
    start = time.time()
    uFD = SystOfEqs.ExactInv()
    end = time.time()
    TIME.append(end-start)
TIME = np.array(TIME)
print('Execution time',np.mean(TIME),'+-',np.std(TIME)/np.sqrt(nmeas),'seconds')
# Out:
# Execution time 0.18710529804229736 +- 0.0009886643932826482 seconds

# %%
u0 = np.zeros(N*N) #Initial guess
nu1, nu2 = 5, 5
TIME = [] 
nmeas = 10
for i in range(nmeas):
    start = time.time()
    uTGM = SystOfEqs.TwoGridMethod(nu1,nu2,u0)
    end = time.time()
    TIME.append(end-start)
TIME = np.array(TIME)
print('Execution time',np.mean(TIME),'+-',np.std(TIME)/np.sqrt(nmeas),'seconds')
# Out:
# Execution time 0.1480032682418823 +- 0.0020561317756586607 seconds

# %%
u0 = np.zeros(N*N) #Initial guess
nu = 10
uGS = SystOfEqs.GaussSeidel(nu,u0)

# %%
for i in range(N):
    for j in range(N):
        string = 'u{:>0}{:>0} | Analytical {:>8} | Exact Inversion {:>8}'+\
              ' | Gauss-Seidel {:>8} | Two-Grid {:>8}' +\
              ' | AMG {:>0} levels {:>8}'
        print(string.format(i+1,j+1,
        np.round(AnalyticSolution(x[i],y[j]),5),
        np.round(uFD[i*N+j],5), 
        np.round(uGS[i*N+j],5),
        np.round(uTGM[i*N+j],5),
        maxl, np.round(uAMG[i*N+j],5)
        ))
# Out:
# u11 | Analytical  0.10864 | Exact Inversion  0.10866 | Gauss-Seidel  0.08808 | Two-Grid  0.10863 | AMG 4 levels  0.10854
# u12 | Analytical  0.09605 | Exact Inversion  0.09608 | Gauss-Seidel  0.05951 | Two-Grid  0.09603 | AMG 4 levels  0.09585
# u13 | Analytical  0.08492 | Exact Inversion  0.08496 | Gauss-Seidel  0.03803 | Two-Grid  0.08488 | AMG 4 levels  0.08462
# u14 | Analytical  0.07507 | Exact Inversion  0.07512 | Gauss-Seidel  0.02309 | Two-Grid  0.07503 | AMG 4 levels   0.0747
# u15 | Analytical  0.06637 | Exact Inversion  0.06642 | Gauss-Seidel  0.01337 | Two-Grid  0.06632 | AMG 4 levels  0.06593
# u16 | Analytical  0.05868 | Exact Inversion  0.05873 | Gauss-Seidel  0.00742 | Two-Grid  0.05863 | AMG 4 levels  0.05819
# u17 | Analytical  0.05188 | Exact Inversion  0.05193 | Gauss-Seidel  0.00396 | Two-Grid  0.05183 | AMG 4 levels  0.05135
# u18 | Analytical  0.04586 | Exact Inversion  0.04592 | Gauss-Seidel  0.00204 | Two-Grid  0.04582 | AMG 4 levels  0.04531
# u19 | Analytical  0.04055 | Exact Inversion   0.0406 | Gauss-Seidel  0.00102 | Two-Grid  0.04051 | AMG 4 levels  0.03997
# u110 | Analytical  0.03585 | Exact Inversion   0.0359 | Gauss-Seidel  0.00049 | Two-Grid  0.03582 | AMG 4 levels  0.03527
# u111 | Analytical  0.03169 | Exact Inversion  0.03175 | Gauss-Seidel  0.00023 | Two-Grid  0.03167 | AMG 4 levels  0.03111
# u112 | Analytical  0.02802 | Exact Inversion  0.02807 | Gauss-Seidel  0.00011 | Two-Grid    0.028 | AMG 4 levels  0.02745
# u113 | Analytical  0.02477 | Exact Inversion  0.02482 | Gauss-Seidel    5e-05 | Two-Grid  0.02476 | AMG 4 levels  0.02421
# u114 | Analytical   0.0219 | Exact Inversion  0.02195 | Gauss-Seidel    2e-05 | Two-Grid   0.0219 | AMG 4 levels  0.02136
# u115 | Analytical  0.01936 | Exact Inversion   0.0194 | Gauss-Seidel    1e-05 | Two-Grid  0.01936 | AMG 4 levels  0.01884
# u116 | Analytical  0.01711 | Exact Inversion  0.01716 | Gauss-Seidel      0.0 | Two-Grid  0.01712 | AMG 4 levels  0.01662
# u117 | Analytical  0.01513 | Exact Inversion  0.01517 | Gauss-Seidel      0.0 | Two-Grid  0.01514 | AMG 4 levels  0.01466
# u118 | Analytical  0.01338 | Exact Inversion  0.01341 | Gauss-Seidel      0.0 | Two-Grid  0.01339 | AMG 4 levels  0.01293
# u119 | Analytical  0.01182 | Exact Inversion  0.01186 | Gauss-Seidel      0.0 | Two-Grid  0.01184 | AMG 4 levels   0.0114
# u120 | Analytical  0.01045 | Exact Inversion  0.01048 | Gauss-Seidel      0.0 | Two-Grid  0.01047 | AMG 4 levels  0.01005
# u121 | Analytical  0.00924 | Exact Inversion  0.00927 | Gauss-Seidel      0.0 | Two-Grid  0.00926 | AMG 4 levels  0.00886
# u122 | Analytical  0.00817 | Exact Inversion  0.00819 | Gauss-Seidel      0.0 | Two-Grid  0.00819 | AMG 4 levels  0.00781
# u123 | Analytical  0.00722 | Exact Inversion  0.00724 | Gauss-Seidel      0.0 | Two-Grid  0.00724 | AMG 4 levels  0.00689
# u124 | Analytical  0.00638 | Exact Inversion   0.0064 | Gauss-Seidel      0.0 | Two-Grid   0.0064 | AMG 4 levels  0.00607
# u125 | Analytical  0.00564 | Exact Inversion  0.00566 | Gauss-Seidel      0.0 | Two-Grid  0.00566 | AMG 4 levels  0.00535
# u126 | Analytical  0.00498 | Exact Inversion    0.005 | Gauss-Seidel      0.0 | Two-Grid    0.005 | AMG 4 levels  0.00472
# u127 | Analytical   0.0044 | Exact Inversion  0.00442 | Gauss-Seidel      0.0 | Two-Grid  0.00442 | AMG 4 levels  0.00415
# u128 | Analytical  0.00389 | Exact Inversion  0.00391 | Gauss-Seidel      0.0 | Two-Grid  0.00391 | AMG 4 levels  0.00366
# u129 | Analytical  0.00344 | Exact Inversion  0.00345 | Gauss-Seidel      0.0 | Two-Grid  0.00345 | AMG 4 levels  0.00322
# u130 | Analytical  0.00303 | Exact Inversion  0.00305 | Gauss-Seidel      0.0 | Two-Grid  0.00305 | AMG 4 levels  0.00284
# u131 | Analytical  0.00268 | Exact Inversion  0.00269 | Gauss-Seidel      0.0 | Two-Grid  0.00269 | AMG 4 levels   0.0025
# u132 | Analytical  0.00236 | Exact Inversion  0.00237 | Gauss-Seidel      0.0 | Two-Grid  0.00237 | AMG 4 levels  0.00219
# u133 | Analytical  0.00208 | Exact Inversion  0.00209 | Gauss-Seidel      0.0 | Two-Grid  0.00209 | AMG 4 levels  0.00193
# u134 | Analytical  0.00184 | Exact Inversion  0.00184 | Gauss-Seidel      0.0 | Two-Grid  0.00184 | AMG 4 levels   0.0017
# u135 | Analytical  0.00162 | Exact Inversion  0.00162 | Gauss-Seidel      0.0 | Two-Grid  0.00162 | AMG 4 levels  0.00149
# u136 | Analytical  0.00142 | Exact Inversion  0.00143 | Gauss-Seidel      0.0 | Two-Grid  0.00143 | AMG 4 levels  0.00131
# u137 | Analytical  0.00125 | Exact Inversion  0.00125 | Gauss-Seidel      0.0 | Two-Grid  0.00125 | AMG 4 levels  0.00114
# u138 | Analytical  0.00109 | Exact Inversion   0.0011 | Gauss-Seidel      0.0 | Two-Grid   0.0011 | AMG 4 levels    0.001
# u139 | Analytical  0.00095 | Exact Inversion  0.00096 | Gauss-Seidel      0.0 | Two-Grid  0.00096 | AMG 4 levels  0.00087
# u140 | Analytical  0.00083 | Exact Inversion  0.00084 | Gauss-Seidel      0.0 | Two-Grid  0.00084 | AMG 4 levels  0.00076
# u141 | Analytical  0.00072 | Exact Inversion  0.00072 | Gauss-Seidel      0.0 | Two-Grid  0.00072 | AMG 4 levels  0.00066
# u142 | Analytical  0.00062 | Exact Inversion  0.00062 | Gauss-Seidel      0.0 | Two-Grid  0.00062 | AMG 4 levels  0.00057
# u143 | Analytical  0.00053 | Exact Inversion  0.00053 | Gauss-Seidel      0.0 | Two-Grid  0.00053 | AMG 4 levels  0.00048
# u144 | Analytical  0.00045 | Exact Inversion  0.00045 | Gauss-Seidel      0.0 | Two-Grid  0.00045 | AMG 4 levels  0.00041
# u145 | Analytical  0.00037 | Exact Inversion  0.00037 | Gauss-Seidel      0.0 | Two-Grid  0.00037 | AMG 4 levels  0.00034
# u146 | Analytical   0.0003 | Exact Inversion   0.0003 | Gauss-Seidel      0.0 | Two-Grid   0.0003 | AMG 4 levels  0.00027
# u147 | Analytical  0.00024 | Exact Inversion  0.00024 | Gauss-Seidel      0.0 | Two-Grid  0.00024 | AMG 4 levels  0.00021
# u148 | Analytical  0.00017 | Exact Inversion  0.00017 | Gauss-Seidel      0.0 | Two-Grid  0.00017 | AMG 4 levels  0.00016
# u149 | Analytical  0.00011 | Exact Inversion  0.00012 | Gauss-Seidel      0.0 | Two-Grid  0.00012 | AMG 4 levels   0.0001
# u150 | Analytical    6e-05 | Exact Inversion    6e-05 | Gauss-Seidel      0.0 | Two-Grid    6e-05 | AMG 4 levels    5e-05
# u21 | Analytical  0.21564 | Exact Inversion  0.21567 | Gauss-Seidel    0.176 | Two-Grid  0.21562 | AMG 4 levels  0.21544
# u22 | Analytical  0.19064 | Exact Inversion   0.1907 | Gauss-Seidel  0.11997 | Two-Grid   0.1906 | AMG 4 levels  0.19025
# u23 | Analytical  0.16855 | Exact Inversion  0.16863 | Gauss-Seidel  0.07749 | Two-Grid  0.16848 | AMG 4 levels  0.16798
# u24 | Analytical  0.14901 | Exact Inversion   0.1491 | Gauss-Seidel  0.04762 | Two-Grid  0.14893 | AMG 4 levels  0.14828
# u25 | Analytical  0.13174 | Exact Inversion  0.13184 | Gauss-Seidel  0.02795 | Two-Grid  0.13165 | AMG 4 levels  0.13089
# u26 | Analytical  0.11647 | Exact Inversion  0.11658 | Gauss-Seidel  0.01573 | Two-Grid  0.11637 | AMG 4 levels  0.11552
# u27 | Analytical  0.10297 | Exact Inversion  0.10308 | Gauss-Seidel  0.00852 | Two-Grid  0.10288 | AMG 4 levels  0.10194
# u28 | Analytical  0.09103 | Exact Inversion  0.09114 | Gauss-Seidel  0.00446 | Two-Grid  0.09095 | AMG 4 levels  0.08995
# u29 | Analytical  0.08048 | Exact Inversion  0.08059 | Gauss-Seidel  0.00226 | Two-Grid  0.08041 | AMG 4 levels  0.07937
# u210 | Analytical  0.07115 | Exact Inversion  0.07126 | Gauss-Seidel  0.00111 | Two-Grid  0.07109 | AMG 4 levels  0.07002
# u211 | Analytical   0.0629 | Exact Inversion  0.06301 | Gauss-Seidel  0.00053 | Two-Grid  0.06286 | AMG 4 levels  0.06178
# u212 | Analytical  0.05561 | Exact Inversion  0.05571 | Gauss-Seidel  0.00025 | Two-Grid  0.05558 | AMG 4 levels   0.0545
# u213 | Analytical  0.04916 | Exact Inversion  0.04926 | Gauss-Seidel  0.00011 | Two-Grid  0.04915 | AMG 4 levels  0.04808
# u214 | Analytical  0.04346 | Exact Inversion  0.04356 | Gauss-Seidel    5e-05 | Two-Grid  0.04346 | AMG 4 levels  0.04242
# u215 | Analytical  0.03842 | Exact Inversion  0.03851 | Gauss-Seidel    2e-05 | Two-Grid  0.03844 | AMG 4 levels  0.03742
# u216 | Analytical  0.03397 | Exact Inversion  0.03405 | Gauss-Seidel    1e-05 | Two-Grid  0.03399 | AMG 4 levels  0.03301
# u217 | Analytical  0.03003 | Exact Inversion  0.03011 | Gauss-Seidel      0.0 | Two-Grid  0.03006 | AMG 4 levels  0.02912
# u218 | Analytical  0.02655 | Exact Inversion  0.02662 | Gauss-Seidel      0.0 | Two-Grid  0.02658 | AMG 4 levels  0.02568
# u219 | Analytical  0.02347 | Exact Inversion  0.02354 | Gauss-Seidel      0.0 | Two-Grid  0.02351 | AMG 4 levels  0.02265
# u220 | Analytical  0.02075 | Exact Inversion  0.02081 | Gauss-Seidel      0.0 | Two-Grid  0.02079 | AMG 4 levels  0.01997
# u221 | Analytical  0.01834 | Exact Inversion   0.0184 | Gauss-Seidel      0.0 | Two-Grid  0.01838 | AMG 4 levels  0.01761
# u222 | Analytical  0.01621 | Exact Inversion  0.01627 | Gauss-Seidel      0.0 | Two-Grid  0.01625 | AMG 4 levels  0.01552
# u223 | Analytical  0.01433 | Exact Inversion  0.01438 | Gauss-Seidel      0.0 | Two-Grid  0.01437 | AMG 4 levels  0.01368
# u224 | Analytical  0.01266 | Exact Inversion  0.01271 | Gauss-Seidel      0.0 | Two-Grid   0.0127 | AMG 4 levels  0.01206
# u225 | Analytical  0.01119 | Exact Inversion  0.01124 | Gauss-Seidel      0.0 | Two-Grid  0.01123 | AMG 4 levels  0.01063
# u226 | Analytical  0.00989 | Exact Inversion  0.00993 | Gauss-Seidel      0.0 | Two-Grid  0.00993 | AMG 4 levels  0.00937
# u227 | Analytical  0.00874 | Exact Inversion  0.00877 | Gauss-Seidel      0.0 | Two-Grid  0.00877 | AMG 4 levels  0.00825
# u228 | Analytical  0.00772 | Exact Inversion  0.00775 | Gauss-Seidel      0.0 | Two-Grid  0.00775 | AMG 4 levels  0.00727
# u229 | Analytical  0.00682 | Exact Inversion  0.00685 | Gauss-Seidel      0.0 | Two-Grid  0.00685 | AMG 4 levels   0.0064
# u230 | Analytical  0.00602 | Exact Inversion  0.00605 | Gauss-Seidel      0.0 | Two-Grid  0.00605 | AMG 4 levels  0.00563
# u231 | Analytical  0.00531 | Exact Inversion  0.00534 | Gauss-Seidel      0.0 | Two-Grid  0.00534 | AMG 4 levels  0.00496
# u232 | Analytical  0.00469 | Exact Inversion  0.00471 | Gauss-Seidel      0.0 | Two-Grid  0.00471 | AMG 4 levels  0.00436
# u233 | Analytical  0.00413 | Exact Inversion  0.00416 | Gauss-Seidel      0.0 | Two-Grid  0.00416 | AMG 4 levels  0.00383
# u234 | Analytical  0.00364 | Exact Inversion  0.00366 | Gauss-Seidel      0.0 | Two-Grid  0.00366 | AMG 4 levels  0.00337
# u235 | Analytical  0.00321 | Exact Inversion  0.00322 | Gauss-Seidel      0.0 | Two-Grid  0.00322 | AMG 4 levels  0.00296
# u236 | Analytical  0.00282 | Exact Inversion  0.00283 | Gauss-Seidel      0.0 | Two-Grid  0.00283 | AMG 4 levels  0.00259
# u237 | Analytical  0.00247 | Exact Inversion  0.00249 | Gauss-Seidel      0.0 | Two-Grid  0.00249 | AMG 4 levels  0.00227
# u238 | Analytical  0.00217 | Exact Inversion  0.00218 | Gauss-Seidel      0.0 | Two-Grid  0.00218 | AMG 4 levels  0.00199
# u239 | Analytical  0.00189 | Exact Inversion  0.00191 | Gauss-Seidel      0.0 | Two-Grid  0.00191 | AMG 4 levels  0.00173
# u240 | Analytical  0.00165 | Exact Inversion  0.00166 | Gauss-Seidel      0.0 | Two-Grid  0.00166 | AMG 4 levels  0.00151
# u241 | Analytical  0.00143 | Exact Inversion  0.00144 | Gauss-Seidel      0.0 | Two-Grid  0.00144 | AMG 4 levels   0.0013
# u242 | Analytical  0.00123 | Exact Inversion  0.00124 | Gauss-Seidel      0.0 | Two-Grid  0.00124 | AMG 4 levels  0.00112
# u243 | Analytical  0.00105 | Exact Inversion  0.00106 | Gauss-Seidel      0.0 | Two-Grid  0.00106 | AMG 4 levels  0.00096
# u244 | Analytical  0.00089 | Exact Inversion  0.00089 | Gauss-Seidel      0.0 | Two-Grid  0.00089 | AMG 4 levels  0.00081
# u245 | Analytical  0.00074 | Exact Inversion  0.00074 | Gauss-Seidel      0.0 | Two-Grid  0.00074 | AMG 4 levels  0.00067
# u246 | Analytical   0.0006 | Exact Inversion   0.0006 | Gauss-Seidel      0.0 | Two-Grid   0.0006 | AMG 4 levels  0.00054
# u247 | Analytical  0.00047 | Exact Inversion  0.00047 | Gauss-Seidel      0.0 | Two-Grid  0.00047 | AMG 4 levels  0.00043
# u248 | Analytical  0.00034 | Exact Inversion  0.00035 | Gauss-Seidel      0.0 | Two-Grid  0.00035 | AMG 4 levels  0.00031
# u249 | Analytical  0.00023 | Exact Inversion  0.00023 | Gauss-Seidel      0.0 | Two-Grid  0.00023 | AMG 4 levels  0.00021
# u250 | Analytical  0.00011 | Exact Inversion  0.00011 | Gauss-Seidel      0.0 | Two-Grid  0.00011 | AMG 4 levels   0.0001
# u31 | Analytical  0.31937 | Exact Inversion  0.31942 | Gauss-Seidel  0.26199 | Two-Grid  0.31934 | AMG 4 levels  0.31907
# u32 | Analytical  0.28235 | Exact Inversion  0.28244 | Gauss-Seidel  0.17981 | Two-Grid  0.28229 | AMG 4 levels  0.28178
# u33 | Analytical  0.24962 | Exact Inversion  0.24974 | Gauss-Seidel  0.11712 | Two-Grid  0.24953 | AMG 4 levels  0.24879
# u34 | Analytical  0.22069 | Exact Inversion  0.22082 | Gauss-Seidel  0.07267 | Two-Grid  0.22058 | AMG 4 levels  0.21964
# u35 | Analytical  0.19511 | Exact Inversion  0.19526 | Gauss-Seidel  0.04311 | Two-Grid  0.19498 | AMG 4 levels  0.19388
# u36 | Analytical  0.17249 | Exact Inversion  0.17265 | Gauss-Seidel  0.02455 | Two-Grid  0.17237 | AMG 4 levels  0.17112
# u37 | Analytical   0.1525 | Exact Inversion  0.15266 | Gauss-Seidel  0.01346 | Two-Grid  0.15237 | AMG 4 levels  0.15101
# u38 | Analytical  0.13482 | Exact Inversion  0.13499 | Gauss-Seidel  0.00714 | Two-Grid  0.13471 | AMG 4 levels  0.13326
# u39 | Analytical  0.11919 | Exact Inversion  0.11936 | Gauss-Seidel  0.00367 | Two-Grid  0.11909 | AMG 4 levels  0.11759
# u310 | Analytical  0.10537 | Exact Inversion  0.10554 | Gauss-Seidel  0.00183 | Two-Grid   0.1053 | AMG 4 levels  0.10375
# u311 | Analytical  0.09316 | Exact Inversion  0.09332 | Gauss-Seidel  0.00089 | Two-Grid   0.0931 | AMG 4 levels  0.09154
# u312 | Analytical  0.08236 | Exact Inversion  0.08251 | Gauss-Seidel  0.00042 | Two-Grid  0.08232 | AMG 4 levels  0.08076
# u313 | Analytical  0.07281 | Exact Inversion  0.07296 | Gauss-Seidel   0.0002 | Two-Grid   0.0728 | AMG 4 levels  0.07125
# u314 | Analytical  0.06437 | Exact Inversion  0.06451 | Gauss-Seidel    9e-05 | Two-Grid  0.06437 | AMG 4 levels  0.06286
# u315 | Analytical  0.05691 | Exact Inversion  0.05704 | Gauss-Seidel    4e-05 | Two-Grid  0.05693 | AMG 4 levels  0.05546
# u316 | Analytical  0.05031 | Exact Inversion  0.05043 | Gauss-Seidel    2e-05 | Two-Grid  0.05034 | AMG 4 levels  0.04892
# u317 | Analytical  0.04447 | Exact Inversion  0.04459 | Gauss-Seidel    1e-05 | Two-Grid  0.04452 | AMG 4 levels  0.04315
# u318 | Analytical  0.03932 | Exact Inversion  0.03943 | Gauss-Seidel      0.0 | Two-Grid  0.03937 | AMG 4 levels  0.03806
# u319 | Analytical  0.03476 | Exact Inversion  0.03486 | Gauss-Seidel      0.0 | Two-Grid  0.03481 | AMG 4 levels  0.03357
# u320 | Analytical  0.03072 | Exact Inversion  0.03082 | Gauss-Seidel      0.0 | Two-Grid  0.03079 | AMG 4 levels   0.0296
# u321 | Analytical  0.02716 | Exact Inversion  0.02725 | Gauss-Seidel      0.0 | Two-Grid  0.02722 | AMG 4 levels   0.0261
# u322 | Analytical  0.02401 | Exact Inversion  0.02409 | Gauss-Seidel      0.0 | Two-Grid  0.02407 | AMG 4 levels  0.02301
# u323 | Analytical  0.02122 | Exact Inversion   0.0213 | Gauss-Seidel      0.0 | Two-Grid  0.02128 | AMG 4 levels  0.02028
# u324 | Analytical  0.01876 | Exact Inversion  0.01883 | Gauss-Seidel      0.0 | Two-Grid  0.01881 | AMG 4 levels  0.01788
# u325 | Analytical  0.01658 | Exact Inversion  0.01664 | Gauss-Seidel      0.0 | Two-Grid  0.01663 | AMG 4 levels  0.01575
# u326 | Analytical  0.01465 | Exact Inversion  0.01471 | Gauss-Seidel      0.0 | Two-Grid   0.0147 | AMG 4 levels  0.01388
# u327 | Analytical  0.01294 | Exact Inversion    0.013 | Gauss-Seidel      0.0 | Two-Grid  0.01299 | AMG 4 levels  0.01223
# u328 | Analytical  0.01143 | Exact Inversion  0.01148 | Gauss-Seidel      0.0 | Two-Grid  0.01148 | AMG 4 levels  0.01077
# u329 | Analytical   0.0101 | Exact Inversion  0.01014 | Gauss-Seidel      0.0 | Two-Grid  0.01014 | AMG 4 levels  0.00948
# u330 | Analytical  0.00892 | Exact Inversion  0.00896 | Gauss-Seidel      0.0 | Two-Grid  0.00896 | AMG 4 levels  0.00835
# u331 | Analytical  0.00787 | Exact Inversion  0.00791 | Gauss-Seidel      0.0 | Two-Grid  0.00791 | AMG 4 levels  0.00734
# u332 | Analytical  0.00694 | Exact Inversion  0.00698 | Gauss-Seidel      0.0 | Two-Grid  0.00698 | AMG 4 levels  0.00646
# u333 | Analytical  0.00612 | Exact Inversion  0.00615 | Gauss-Seidel      0.0 | Two-Grid  0.00615 | AMG 4 levels  0.00568
# u334 | Analytical   0.0054 | Exact Inversion  0.00542 | Gauss-Seidel      0.0 | Two-Grid  0.00542 | AMG 4 levels  0.00499
# u335 | Analytical  0.00475 | Exact Inversion  0.00477 | Gauss-Seidel      0.0 | Two-Grid  0.00477 | AMG 4 levels  0.00438
# u336 | Analytical  0.00418 | Exact Inversion   0.0042 | Gauss-Seidel      0.0 | Two-Grid   0.0042 | AMG 4 levels  0.00384
# u337 | Analytical  0.00367 | Exact Inversion  0.00369 | Gauss-Seidel      0.0 | Two-Grid  0.00369 | AMG 4 levels  0.00337
# u338 | Analytical  0.00321 | Exact Inversion  0.00323 | Gauss-Seidel      0.0 | Two-Grid  0.00323 | AMG 4 levels  0.00294
# u339 | Analytical   0.0028 | Exact Inversion  0.00282 | Gauss-Seidel      0.0 | Two-Grid  0.00282 | AMG 4 levels  0.00257
# u340 | Analytical  0.00244 | Exact Inversion  0.00246 | Gauss-Seidel      0.0 | Two-Grid  0.00246 | AMG 4 levels  0.00223
# u341 | Analytical  0.00212 | Exact Inversion  0.00213 | Gauss-Seidel      0.0 | Two-Grid  0.00213 | AMG 4 levels  0.00193
# u342 | Analytical  0.00182 | Exact Inversion  0.00183 | Gauss-Seidel      0.0 | Two-Grid  0.00183 | AMG 4 levels  0.00166
# u343 | Analytical  0.00156 | Exact Inversion  0.00157 | Gauss-Seidel      0.0 | Two-Grid  0.00157 | AMG 4 levels  0.00142
# u344 | Analytical  0.00131 | Exact Inversion  0.00132 | Gauss-Seidel      0.0 | Two-Grid  0.00132 | AMG 4 levels  0.00119
# u345 | Analytical  0.00109 | Exact Inversion   0.0011 | Gauss-Seidel      0.0 | Two-Grid   0.0011 | AMG 4 levels  0.00099
# u346 | Analytical  0.00088 | Exact Inversion  0.00089 | Gauss-Seidel      0.0 | Two-Grid  0.00089 | AMG 4 levels   0.0008
# u347 | Analytical  0.00069 | Exact Inversion   0.0007 | Gauss-Seidel      0.0 | Two-Grid   0.0007 | AMG 4 levels  0.00063
# u348 | Analytical  0.00051 | Exact Inversion  0.00051 | Gauss-Seidel      0.0 | Two-Grid  0.00051 | AMG 4 levels  0.00046
# u349 | Analytical  0.00034 | Exact Inversion  0.00034 | Gauss-Seidel      0.0 | Two-Grid  0.00034 | AMG 4 levels   0.0003
# u350 | Analytical  0.00017 | Exact Inversion  0.00017 | Gauss-Seidel      0.0 | Two-Grid  0.00017 | AMG 4 levels  0.00015
# u41 | Analytical  0.41826 | Exact Inversion  0.41832 | Gauss-Seidel  0.34447 | Two-Grid  0.41822 | AMG 4 levels  0.41788
# u42 | Analytical  0.36977 | Exact Inversion  0.36989 | Gauss-Seidel  0.23769 | Two-Grid   0.3697 | AMG 4 levels  0.36904
# u43 | Analytical  0.32691 | Exact Inversion  0.32706 | Gauss-Seidel  0.15585 | Two-Grid  0.32681 | AMG 4 levels  0.32586
# u44 | Analytical  0.28902 | Exact Inversion   0.2892 | Gauss-Seidel  0.09745 | Two-Grid  0.28888 | AMG 4 levels  0.28769
# u45 | Analytical  0.25552 | Exact Inversion  0.25572 | Gauss-Seidel  0.05832 | Two-Grid  0.25537 | AMG 4 levels  0.25396
# u46 | Analytical   0.2259 | Exact Inversion  0.22611 | Gauss-Seidel  0.03352 | Two-Grid  0.22574 | AMG 4 levels  0.22415
# u47 | Analytical  0.19971 | Exact Inversion  0.19993 | Gauss-Seidel  0.01857 | Two-Grid  0.19957 | AMG 4 levels  0.19783
# u48 | Analytical  0.17656 | Exact Inversion  0.17678 | Gauss-Seidel  0.00995 | Two-Grid  0.17642 | AMG 4 levels  0.17458
# u49 | Analytical   0.1561 | Exact Inversion  0.15631 | Gauss-Seidel  0.00517 | Two-Grid  0.15598 | AMG 4 levels  0.15406
# u410 | Analytical    0.138 | Exact Inversion  0.13822 | Gauss-Seidel  0.00261 | Two-Grid  0.13791 | AMG 4 levels  0.13594
# u411 | Analytical    0.122 | Exact Inversion  0.12221 | Gauss-Seidel  0.00128 | Two-Grid  0.12194 | AMG 4 levels  0.11995
# u412 | Analytical  0.10786 | Exact Inversion  0.10806 | Gauss-Seidel  0.00062 | Two-Grid  0.10782 | AMG 4 levels  0.10583
# u413 | Analytical  0.09536 | Exact Inversion  0.09555 | Gauss-Seidel  0.00029 | Two-Grid  0.09534 | AMG 4 levels  0.09338
# u414 | Analytical   0.0843 | Exact Inversion  0.08448 | Gauss-Seidel  0.00013 | Two-Grid  0.08431 | AMG 4 levels  0.08238
# u415 | Analytical  0.07453 | Exact Inversion   0.0747 | Gauss-Seidel    6e-05 | Two-Grid  0.07456 | AMG 4 levels  0.07268
# u416 | Analytical  0.06589 | Exact Inversion  0.06605 | Gauss-Seidel    3e-05 | Two-Grid  0.06593 | AMG 4 levels  0.06412
# u417 | Analytical  0.05825 | Exact Inversion   0.0584 | Gauss-Seidel    1e-05 | Two-Grid   0.0583 | AMG 4 levels  0.05656
# u418 | Analytical  0.05149 | Exact Inversion  0.05164 | Gauss-Seidel      0.0 | Two-Grid  0.05156 | AMG 4 levels  0.04989
# u419 | Analytical  0.04552 | Exact Inversion  0.04565 | Gauss-Seidel      0.0 | Two-Grid   0.0456 | AMG 4 levels    0.044
# u420 | Analytical  0.04024 | Exact Inversion  0.04036 | Gauss-Seidel      0.0 | Two-Grid  0.04032 | AMG 4 levels   0.0388
# u421 | Analytical  0.03557 | Exact Inversion  0.03569 | Gauss-Seidel      0.0 | Two-Grid  0.03565 | AMG 4 levels  0.03421
# u422 | Analytical  0.03144 | Exact Inversion  0.03155 | Gauss-Seidel      0.0 | Two-Grid  0.03152 | AMG 4 levels  0.03016
# u423 | Analytical  0.02779 | Exact Inversion  0.02789 | Gauss-Seidel      0.0 | Two-Grid  0.02787 | AMG 4 levels  0.02659
# u424 | Analytical  0.02456 | Exact Inversion  0.02465 | Gauss-Seidel      0.0 | Two-Grid  0.02464 | AMG 4 levels  0.02343
# u425 | Analytical  0.02171 | Exact Inversion  0.02179 | Gauss-Seidel      0.0 | Two-Grid  0.02178 | AMG 4 levels  0.02065
# u426 | Analytical  0.01918 | Exact Inversion  0.01926 | Gauss-Seidel      0.0 | Two-Grid  0.01925 | AMG 4 levels   0.0182
# u427 | Analytical  0.01695 | Exact Inversion  0.01702 | Gauss-Seidel      0.0 | Two-Grid  0.01701 | AMG 4 levels  0.01603
# u428 | Analytical  0.01497 | Exact Inversion  0.01504 | Gauss-Seidel      0.0 | Two-Grid  0.01503 | AMG 4 levels  0.01412
# u429 | Analytical  0.01322 | Exact Inversion  0.01328 | Gauss-Seidel      0.0 | Two-Grid  0.01328 | AMG 4 levels  0.01243
# u430 | Analytical  0.01168 | Exact Inversion  0.01173 | Gauss-Seidel      0.0 | Two-Grid  0.01173 | AMG 4 levels  0.01094
# u431 | Analytical  0.01031 | Exact Inversion  0.01036 | Gauss-Seidel      0.0 | Two-Grid  0.01036 | AMG 4 levels  0.00962
# u432 | Analytical  0.00909 | Exact Inversion  0.00914 | Gauss-Seidel      0.0 | Two-Grid  0.00914 | AMG 4 levels  0.00847
# u433 | Analytical  0.00802 | Exact Inversion  0.00806 | Gauss-Seidel      0.0 | Two-Grid  0.00806 | AMG 4 levels  0.00744
# u434 | Analytical  0.00707 | Exact Inversion   0.0071 | Gauss-Seidel      0.0 | Two-Grid   0.0071 | AMG 4 levels  0.00654
# u435 | Analytical  0.00622 | Exact Inversion  0.00625 | Gauss-Seidel      0.0 | Two-Grid  0.00625 | AMG 4 levels  0.00574
# u436 | Analytical  0.00547 | Exact Inversion   0.0055 | Gauss-Seidel      0.0 | Two-Grid   0.0055 | AMG 4 levels  0.00503
# u437 | Analytical   0.0048 | Exact Inversion  0.00483 | Gauss-Seidel      0.0 | Two-Grid  0.00483 | AMG 4 levels  0.00441
# u438 | Analytical   0.0042 | Exact Inversion  0.00423 | Gauss-Seidel      0.0 | Two-Grid  0.00423 | AMG 4 levels  0.00385
# u439 | Analytical  0.00367 | Exact Inversion   0.0037 | Gauss-Seidel      0.0 | Two-Grid  0.00369 | AMG 4 levels  0.00336
# u440 | Analytical   0.0032 | Exact Inversion  0.00322 | Gauss-Seidel      0.0 | Two-Grid  0.00322 | AMG 4 levels  0.00292
# u441 | Analytical  0.00277 | Exact Inversion  0.00279 | Gauss-Seidel      0.0 | Two-Grid  0.00279 | AMG 4 levels  0.00253
# u442 | Analytical  0.00239 | Exact Inversion   0.0024 | Gauss-Seidel      0.0 | Two-Grid   0.0024 | AMG 4 levels  0.00217
# u443 | Analytical  0.00204 | Exact Inversion  0.00205 | Gauss-Seidel      0.0 | Two-Grid  0.00205 | AMG 4 levels  0.00185
# u444 | Analytical  0.00172 | Exact Inversion  0.00173 | Gauss-Seidel      0.0 | Two-Grid  0.00173 | AMG 4 levels  0.00156
# u445 | Analytical  0.00143 | Exact Inversion  0.00144 | Gauss-Seidel      0.0 | Two-Grid  0.00144 | AMG 4 levels   0.0013
# u446 | Analytical  0.00116 | Exact Inversion  0.00117 | Gauss-Seidel      0.0 | Two-Grid  0.00117 | AMG 4 levels  0.00105
# u447 | Analytical  0.00091 | Exact Inversion  0.00091 | Gauss-Seidel      0.0 | Two-Grid  0.00091 | AMG 4 levels  0.00082
# u448 | Analytical  0.00067 | Exact Inversion  0.00067 | Gauss-Seidel      0.0 | Two-Grid  0.00067 | AMG 4 levels  0.00061
# u449 | Analytical  0.00044 | Exact Inversion  0.00044 | Gauss-Seidel      0.0 | Two-Grid  0.00044 | AMG 4 levels   0.0004
# u450 | Analytical  0.00022 | Exact Inversion  0.00022 | Gauss-Seidel      0.0 | Two-Grid  0.00022 | AMG 4 levels   0.0002
# u51 | Analytical   0.5108 | Exact Inversion  0.51088 | Gauss-Seidel    0.422 | Two-Grid  0.51076 | AMG 4 levels  0.51036
# u52 | Analytical  0.45159 | Exact Inversion  0.45173 | Gauss-Seidel  0.29243 | Two-Grid  0.45151 | AMG 4 levels  0.45073
# u53 | Analytical  0.39925 | Exact Inversion  0.39943 | Gauss-Seidel  0.19277 | Two-Grid  0.39912 | AMG 4 levels    0.398
# u54 | Analytical  0.35297 | Exact Inversion  0.35319 | Gauss-Seidel  0.12129 | Two-Grid  0.35282 | AMG 4 levels   0.3514
# u55 | Analytical  0.31205 | Exact Inversion   0.3123 | Gauss-Seidel   0.0731 | Two-Grid  0.31188 | AMG 4 levels  0.31021
# u56 | Analytical  0.27588 | Exact Inversion  0.27614 | Gauss-Seidel  0.04235 | Two-Grid  0.27571 | AMG 4 levels  0.27382
# u57 | Analytical   0.2439 | Exact Inversion  0.24417 | Gauss-Seidel  0.02366 | Two-Grid  0.24373 | AMG 4 levels  0.24167
# u58 | Analytical  0.21563 | Exact Inversion   0.2159 | Gauss-Seidel  0.01279 | Two-Grid  0.21548 | AMG 4 levels  0.21329
# u59 | Analytical  0.19063 | Exact Inversion   0.1909 | Gauss-Seidel  0.00671 | Two-Grid   0.1905 | AMG 4 levels  0.18822
# u510 | Analytical  0.16854 | Exact Inversion   0.1688 | Gauss-Seidel  0.00342 | Two-Grid  0.16843 | AMG 4 levels   0.1661
# u511 | Analytical    0.149 | Exact Inversion  0.14925 | Gauss-Seidel   0.0017 | Two-Grid  0.14892 | AMG 4 levels  0.14656
# u512 | Analytical  0.13173 | Exact Inversion  0.13197 | Gauss-Seidel  0.00082 | Two-Grid  0.13168 | AMG 4 levels  0.12933
# u513 | Analytical  0.11645 | Exact Inversion  0.11669 | Gauss-Seidel  0.00039 | Two-Grid  0.11644 | AMG 4 levels  0.11411
# u514 | Analytical  0.10295 | Exact Inversion  0.10318 | Gauss-Seidel  0.00018 | Two-Grid  0.10297 | AMG 4 levels  0.10068
# u515 | Analytical  0.09102 | Exact Inversion  0.09123 | Gauss-Seidel    8e-05 | Two-Grid  0.09105 | AMG 4 levels  0.08883
# u516 | Analytical  0.08046 | Exact Inversion  0.08066 | Gauss-Seidel    4e-05 | Two-Grid  0.08052 | AMG 4 levels  0.07836
# u517 | Analytical  0.07113 | Exact Inversion  0.07132 | Gauss-Seidel    2e-05 | Two-Grid  0.07121 | AMG 4 levels  0.06913
# u518 | Analytical  0.06288 | Exact Inversion  0.06306 | Gauss-Seidel    1e-05 | Two-Grid  0.06297 | AMG 4 levels  0.06098
# u519 | Analytical  0.05559 | Exact Inversion  0.05575 | Gauss-Seidel      0.0 | Two-Grid  0.05568 | AMG 4 levels  0.05378
# u520 | Analytical  0.04914 | Exact Inversion  0.04929 | Gauss-Seidel      0.0 | Two-Grid  0.04924 | AMG 4 levels  0.04743
# u521 | Analytical  0.04344 | Exact Inversion  0.04358 | Gauss-Seidel      0.0 | Two-Grid  0.04354 | AMG 4 levels  0.04182
# u522 | Analytical   0.0384 | Exact Inversion  0.03853 | Gauss-Seidel      0.0 | Two-Grid   0.0385 | AMG 4 levels  0.03687
# u523 | Analytical  0.03394 | Exact Inversion  0.03406 | Gauss-Seidel      0.0 | Two-Grid  0.03404 | AMG 4 levels   0.0325
# u524 | Analytical     0.03 | Exact Inversion  0.03011 | Gauss-Seidel      0.0 | Two-Grid  0.03009 | AMG 4 levels  0.02865
# u525 | Analytical  0.02651 | Exact Inversion  0.02661 | Gauss-Seidel      0.0 | Two-Grid   0.0266 | AMG 4 levels  0.02525
# u526 | Analytical  0.02343 | Exact Inversion  0.02352 | Gauss-Seidel      0.0 | Two-Grid  0.02351 | AMG 4 levels  0.02224
# u527 | Analytical   0.0207 | Exact Inversion  0.02079 | Gauss-Seidel      0.0 | Two-Grid  0.02078 | AMG 4 levels  0.01959
# u528 | Analytical  0.01829 | Exact Inversion  0.01837 | Gauss-Seidel      0.0 | Two-Grid  0.01836 | AMG 4 levels  0.01725
# u529 | Analytical  0.01615 | Exact Inversion  0.01622 | Gauss-Seidel      0.0 | Two-Grid  0.01622 | AMG 4 levels  0.01519
# u530 | Analytical  0.01426 | Exact Inversion  0.01433 | Gauss-Seidel      0.0 | Two-Grid  0.01433 | AMG 4 levels  0.01337
# u531 | Analytical  0.01259 | Exact Inversion  0.01265 | Gauss-Seidel      0.0 | Two-Grid  0.01265 | AMG 4 levels  0.01176
# u532 | Analytical  0.01111 | Exact Inversion  0.01116 | Gauss-Seidel      0.0 | Two-Grid  0.01116 | AMG 4 levels  0.01034
# u533 | Analytical  0.00979 | Exact Inversion  0.00984 | Gauss-Seidel      0.0 | Two-Grid  0.00984 | AMG 4 levels  0.00909
# u534 | Analytical  0.00863 | Exact Inversion  0.00867 | Gauss-Seidel      0.0 | Two-Grid  0.00867 | AMG 4 levels  0.00799
# u535 | Analytical   0.0076 | Exact Inversion  0.00764 | Gauss-Seidel      0.0 | Two-Grid  0.00764 | AMG 4 levels  0.00701
# u536 | Analytical  0.00668 | Exact Inversion  0.00671 | Gauss-Seidel      0.0 | Two-Grid  0.00671 | AMG 4 levels  0.00615
# u537 | Analytical  0.00586 | Exact Inversion   0.0059 | Gauss-Seidel      0.0 | Two-Grid   0.0059 | AMG 4 levels  0.00538
# u538 | Analytical  0.00514 | Exact Inversion  0.00516 | Gauss-Seidel      0.0 | Two-Grid  0.00516 | AMG 4 levels   0.0047
# u539 | Analytical  0.00449 | Exact Inversion  0.00451 | Gauss-Seidel      0.0 | Two-Grid  0.00451 | AMG 4 levels   0.0041
# u540 | Analytical  0.00391 | Exact Inversion  0.00393 | Gauss-Seidel      0.0 | Two-Grid  0.00393 | AMG 4 levels  0.00356
# u541 | Analytical  0.00338 | Exact Inversion   0.0034 | Gauss-Seidel      0.0 | Two-Grid   0.0034 | AMG 4 levels  0.00308
# u542 | Analytical  0.00291 | Exact Inversion  0.00293 | Gauss-Seidel      0.0 | Two-Grid  0.00293 | AMG 4 levels  0.00265
# u543 | Analytical  0.00249 | Exact Inversion   0.0025 | Gauss-Seidel      0.0 | Two-Grid   0.0025 | AMG 4 levels  0.00226
# u544 | Analytical   0.0021 | Exact Inversion  0.00211 | Gauss-Seidel      0.0 | Two-Grid  0.00211 | AMG 4 levels  0.00191
# u545 | Analytical  0.00174 | Exact Inversion  0.00176 | Gauss-Seidel      0.0 | Two-Grid  0.00176 | AMG 4 levels  0.00158
# u546 | Analytical  0.00141 | Exact Inversion  0.00142 | Gauss-Seidel      0.0 | Two-Grid  0.00142 | AMG 4 levels  0.00128
# u547 | Analytical  0.00111 | Exact Inversion  0.00111 | Gauss-Seidel      0.0 | Two-Grid  0.00111 | AMG 4 levels    0.001
# u548 | Analytical  0.00082 | Exact Inversion  0.00082 | Gauss-Seidel      0.0 | Two-Grid  0.00082 | AMG 4 levels  0.00074
# u549 | Analytical  0.00054 | Exact Inversion  0.00054 | Gauss-Seidel      0.0 | Two-Grid  0.00054 | AMG 4 levels  0.00049
# u550 | Analytical  0.00027 | Exact Inversion  0.00027 | Gauss-Seidel      0.0 | Two-Grid  0.00027 | AMG 4 levels  0.00024
# u61 | Analytical  0.59561 | Exact Inversion   0.5957 | Gauss-Seidel   0.4933 | Two-Grid  0.59556 | AMG 4 levels  0.59511
# u62 | Analytical  0.52657 | Exact Inversion  0.52673 | Gauss-Seidel  0.34302 | Two-Grid  0.52647 | AMG 4 levels   0.5256
# u63 | Analytical  0.46553 | Exact Inversion  0.46575 | Gauss-Seidel   0.2271 | Two-Grid   0.4654 | AMG 4 levels  0.46414
# u64 | Analytical  0.41157 | Exact Inversion  0.41182 | Gauss-Seidel  0.14362 | Two-Grid   0.4114 | AMG 4 levels   0.4098
# u65 | Analytical  0.36386 | Exact Inversion  0.36414 | Gauss-Seidel  0.08707 | Two-Grid  0.36368 | AMG 4 levels  0.36179
# u66 | Analytical  0.32168 | Exact Inversion  0.32198 | Gauss-Seidel  0.05077 | Two-Grid  0.32149 | AMG 4 levels  0.31935
# u67 | Analytical   0.2844 | Exact Inversion   0.2847 | Gauss-Seidel  0.02857 | Two-Grid  0.28421 | AMG 4 levels  0.28188
# u68 | Analytical  0.25143 | Exact Inversion  0.25174 | Gauss-Seidel  0.01556 | Two-Grid  0.25125 | AMG 4 levels  0.24878
# u69 | Analytical  0.22228 | Exact Inversion  0.22259 | Gauss-Seidel  0.00822 | Two-Grid  0.22214 | AMG 4 levels  0.21956
# u610 | Analytical  0.19652 | Exact Inversion  0.19682 | Gauss-Seidel  0.00423 | Two-Grid   0.1964 | AMG 4 levels  0.19376
# u611 | Analytical  0.17374 | Exact Inversion  0.17403 | Gauss-Seidel  0.00212 | Two-Grid  0.17365 | AMG 4 levels  0.17099
# u612 | Analytical  0.15359 | Exact Inversion  0.15388 | Gauss-Seidel  0.00104 | Two-Grid  0.15355 | AMG 4 levels  0.15088
# u613 | Analytical  0.13579 | Exact Inversion  0.13606 | Gauss-Seidel   0.0005 | Two-Grid  0.13578 | AMG 4 levels  0.13314
# u614 | Analytical  0.12005 | Exact Inversion  0.12031 | Gauss-Seidel  0.00023 | Two-Grid  0.12006 | AMG 4 levels  0.11747
# u615 | Analytical  0.10613 | Exact Inversion  0.10638 | Gauss-Seidel  0.00011 | Two-Grid  0.10617 | AMG 4 levels  0.10365
# u616 | Analytical  0.09382 | Exact Inversion  0.09406 | Gauss-Seidel    5e-05 | Two-Grid  0.09389 | AMG 4 levels  0.09144
# u617 | Analytical  0.08294 | Exact Inversion  0.08316 | Gauss-Seidel    2e-05 | Two-Grid  0.08303 | AMG 4 levels  0.08067
# u618 | Analytical  0.07332 | Exact Inversion  0.07353 | Gauss-Seidel    1e-05 | Two-Grid  0.07342 | AMG 4 levels  0.07116
# u619 | Analytical  0.06482 | Exact Inversion  0.06501 | Gauss-Seidel      0.0 | Two-Grid  0.06493 | AMG 4 levels  0.06276
# u620 | Analytical   0.0573 | Exact Inversion  0.05748 | Gauss-Seidel      0.0 | Two-Grid  0.05742 | AMG 4 levels  0.05535
# u621 | Analytical  0.05065 | Exact Inversion  0.05082 | Gauss-Seidel      0.0 | Two-Grid  0.05077 | AMG 4 levels  0.04881
# u622 | Analytical  0.04477 | Exact Inversion  0.04493 | Gauss-Seidel      0.0 | Two-Grid  0.04489 | AMG 4 levels  0.04303
# u623 | Analytical  0.03957 | Exact Inversion  0.03972 | Gauss-Seidel      0.0 | Two-Grid  0.03969 | AMG 4 levels  0.03794
# u624 | Analytical  0.03498 | Exact Inversion  0.03511 | Gauss-Seidel      0.0 | Two-Grid  0.03509 | AMG 4 levels  0.03344
# u625 | Analytical  0.03091 | Exact Inversion  0.03103 | Gauss-Seidel      0.0 | Two-Grid  0.03102 | AMG 4 levels  0.02946
# u626 | Analytical  0.02732 | Exact Inversion  0.02743 | Gauss-Seidel      0.0 | Two-Grid  0.02742 | AMG 4 levels  0.02596
# u627 | Analytical  0.02414 | Exact Inversion  0.02424 | Gauss-Seidel      0.0 | Two-Grid  0.02423 | AMG 4 levels  0.02287
# u628 | Analytical  0.02132 | Exact Inversion  0.02141 | Gauss-Seidel      0.0 | Two-Grid  0.02141 | AMG 4 levels  0.02014
# u629 | Analytical  0.01883 | Exact Inversion  0.01892 | Gauss-Seidel      0.0 | Two-Grid  0.01891 | AMG 4 levels  0.01773
# u630 | Analytical  0.01663 | Exact Inversion  0.01671 | Gauss-Seidel      0.0 | Two-Grid   0.0167 | AMG 4 levels   0.0156
# u631 | Analytical  0.01468 | Exact Inversion  0.01475 | Gauss-Seidel      0.0 | Two-Grid  0.01475 | AMG 4 levels  0.01372
# u632 | Analytical  0.01295 | Exact Inversion  0.01301 | Gauss-Seidel      0.0 | Two-Grid  0.01301 | AMG 4 levels  0.01207
# u633 | Analytical  0.01142 | Exact Inversion  0.01148 | Gauss-Seidel      0.0 | Two-Grid  0.01148 | AMG 4 levels  0.01061
# u634 | Analytical  0.01006 | Exact Inversion  0.01011 | Gauss-Seidel      0.0 | Two-Grid  0.01011 | AMG 4 levels  0.00932
# u635 | Analytical  0.00886 | Exact Inversion   0.0089 | Gauss-Seidel      0.0 | Two-Grid   0.0089 | AMG 4 levels  0.00818
# u636 | Analytical  0.00779 | Exact Inversion  0.00783 | Gauss-Seidel      0.0 | Two-Grid  0.00783 | AMG 4 levels  0.00717
# u637 | Analytical  0.00684 | Exact Inversion  0.00687 | Gauss-Seidel      0.0 | Two-Grid  0.00687 | AMG 4 levels  0.00627
# u638 | Analytical  0.00599 | Exact Inversion  0.00602 | Gauss-Seidel      0.0 | Two-Grid  0.00602 | AMG 4 levels  0.00548
# u639 | Analytical  0.00523 | Exact Inversion  0.00526 | Gauss-Seidel      0.0 | Two-Grid  0.00526 | AMG 4 levels  0.00478
# u640 | Analytical  0.00455 | Exact Inversion  0.00458 | Gauss-Seidel      0.0 | Two-Grid  0.00458 | AMG 4 levels  0.00415
# u641 | Analytical  0.00395 | Exact Inversion  0.00397 | Gauss-Seidel      0.0 | Two-Grid  0.00397 | AMG 4 levels  0.00359
# u642 | Analytical   0.0034 | Exact Inversion  0.00342 | Gauss-Seidel      0.0 | Two-Grid  0.00342 | AMG 4 levels  0.00309
# u643 | Analytical   0.0029 | Exact Inversion  0.00292 | Gauss-Seidel      0.0 | Two-Grid  0.00292 | AMG 4 levels  0.00263
# u644 | Analytical  0.00245 | Exact Inversion  0.00246 | Gauss-Seidel      0.0 | Two-Grid  0.00246 | AMG 4 levels  0.00222
# u645 | Analytical  0.00203 | Exact Inversion  0.00205 | Gauss-Seidel      0.0 | Two-Grid  0.00205 | AMG 4 levels  0.00184
# u646 | Analytical  0.00165 | Exact Inversion  0.00166 | Gauss-Seidel      0.0 | Two-Grid  0.00166 | AMG 4 levels  0.00149
# u647 | Analytical  0.00129 | Exact Inversion   0.0013 | Gauss-Seidel      0.0 | Two-Grid   0.0013 | AMG 4 levels  0.00117
# u648 | Analytical  0.00095 | Exact Inversion  0.00096 | Gauss-Seidel      0.0 | Two-Grid  0.00096 | AMG 4 levels  0.00086
# u649 | Analytical  0.00063 | Exact Inversion  0.00063 | Gauss-Seidel      0.0 | Two-Grid  0.00063 | AMG 4 levels  0.00056
# u650 | Analytical  0.00031 | Exact Inversion  0.00031 | Gauss-Seidel      0.0 | Two-Grid  0.00031 | AMG 4 levels  0.00028
# u71 | Analytical  0.67138 | Exact Inversion  0.67148 | Gauss-Seidel   0.5572 | Two-Grid  0.67133 | AMG 4 levels  0.67084
# u72 | Analytical  0.59356 | Exact Inversion  0.59374 | Gauss-Seidel  0.38856 | Two-Grid  0.59346 | AMG 4 levels  0.59251
# u73 | Analytical  0.52476 | Exact Inversion    0.525 | Gauss-Seidel  0.25817 | Two-Grid  0.52461 | AMG 4 levels  0.52324
# u74 | Analytical  0.46393 | Exact Inversion  0.46422 | Gauss-Seidel  0.16397 | Two-Grid  0.46375 | AMG 4 levels  0.46201
# u75 | Analytical  0.41015 | Exact Inversion  0.41047 | Gauss-Seidel  0.09989 | Two-Grid  0.40995 | AMG 4 levels  0.40789
# u76 | Analytical  0.36261 | Exact Inversion  0.36295 | Gauss-Seidel  0.05857 | Two-Grid   0.3624 | AMG 4 levels  0.36008
# u77 | Analytical  0.32058 | Exact Inversion  0.32093 | Gauss-Seidel  0.03315 | Two-Grid  0.32037 | AMG 4 levels  0.31783
# u78 | Analytical  0.28342 | Exact Inversion  0.28377 | Gauss-Seidel  0.01817 | Two-Grid  0.28323 | AMG 4 levels  0.28054
# u79 | Analytical  0.25056 | Exact Inversion  0.25091 | Gauss-Seidel  0.00967 | Two-Grid   0.2504 | AMG 4 levels  0.24759
# u710 | Analytical  0.22152 | Exact Inversion  0.22186 | Gauss-Seidel  0.00501 | Two-Grid   0.2214 | AMG 4 levels  0.21851
# u711 | Analytical  0.19584 | Exact Inversion  0.19617 | Gauss-Seidel  0.00253 | Two-Grid  0.19575 | AMG 4 levels  0.19283
# u712 | Analytical  0.17314 | Exact Inversion  0.17346 | Gauss-Seidel  0.00125 | Two-Grid  0.17309 | AMG 4 levels  0.17017
# u713 | Analytical  0.15306 | Exact Inversion  0.15337 | Gauss-Seidel   0.0006 | Two-Grid  0.15305 | AMG 4 levels  0.15016
# u714 | Analytical  0.13532 | Exact Inversion  0.13561 | Gauss-Seidel  0.00029 | Two-Grid  0.13534 | AMG 4 levels   0.1325
# u715 | Analytical  0.11963 | Exact Inversion  0.11991 | Gauss-Seidel  0.00013 | Two-Grid  0.11968 | AMG 4 levels  0.11691
# u716 | Analytical  0.10576 | Exact Inversion  0.10602 | Gauss-Seidel    6e-05 | Two-Grid  0.10584 | AMG 4 levels  0.10315
# u717 | Analytical   0.0935 | Exact Inversion  0.09374 | Gauss-Seidel    3e-05 | Two-Grid  0.09359 | AMG 4 levels    0.091
# u718 | Analytical  0.08265 | Exact Inversion  0.08288 | Gauss-Seidel    1e-05 | Two-Grid  0.08277 | AMG 4 levels  0.08028
# u719 | Analytical  0.07307 | Exact Inversion  0.07328 | Gauss-Seidel    1e-05 | Two-Grid  0.07319 | AMG 4 levels  0.07081
# u720 | Analytical  0.06459 | Exact Inversion  0.06479 | Gauss-Seidel      0.0 | Two-Grid  0.06472 | AMG 4 levels  0.06245
# u721 | Analytical   0.0571 | Exact Inversion  0.05728 | Gauss-Seidel      0.0 | Two-Grid  0.05723 | AMG 4 levels  0.05507
# u722 | Analytical  0.05047 | Exact Inversion  0.05064 | Gauss-Seidel      0.0 | Two-Grid   0.0506 | AMG 4 levels  0.04855
# u723 | Analytical  0.04461 | Exact Inversion  0.04477 | Gauss-Seidel      0.0 | Two-Grid  0.04474 | AMG 4 levels   0.0428
# u724 | Analytical  0.03943 | Exact Inversion  0.03957 | Gauss-Seidel      0.0 | Two-Grid  0.03955 | AMG 4 levels  0.03772
# u725 | Analytical  0.03484 | Exact Inversion  0.03498 | Gauss-Seidel      0.0 | Two-Grid  0.03496 | AMG 4 levels  0.03324
# u726 | Analytical  0.03079 | Exact Inversion  0.03092 | Gauss-Seidel      0.0 | Two-Grid   0.0309 | AMG 4 levels  0.02929
# u727 | Analytical  0.02721 | Exact Inversion  0.02732 | Gauss-Seidel      0.0 | Two-Grid  0.02731 | AMG 4 levels   0.0258
# u728 | Analytical  0.02403 | Exact Inversion  0.02414 | Gauss-Seidel      0.0 | Two-Grid  0.02413 | AMG 4 levels  0.02272
# u729 | Analytical  0.02123 | Exact Inversion  0.02132 | Gauss-Seidel      0.0 | Two-Grid  0.02132 | AMG 4 levels     0.02
# u730 | Analytical  0.01874 | Exact Inversion  0.01883 | Gauss-Seidel      0.0 | Two-Grid  0.01883 | AMG 4 levels   0.0176
# u731 | Analytical  0.01654 | Exact Inversion  0.01662 | Gauss-Seidel      0.0 | Two-Grid  0.01662 | AMG 4 levels  0.01548
# u732 | Analytical   0.0146 | Exact Inversion  0.01467 | Gauss-Seidel      0.0 | Two-Grid  0.01467 | AMG 4 levels  0.01361
# u733 | Analytical  0.01287 | Exact Inversion  0.01294 | Gauss-Seidel      0.0 | Two-Grid  0.01294 | AMG 4 levels  0.01196
# u734 | Analytical  0.01134 | Exact Inversion   0.0114 | Gauss-Seidel      0.0 | Two-Grid   0.0114 | AMG 4 levels   0.0105
# u735 | Analytical  0.00998 | Exact Inversion  0.01004 | Gauss-Seidel      0.0 | Two-Grid  0.01004 | AMG 4 levels  0.00922
# u736 | Analytical  0.00878 | Exact Inversion  0.00883 | Gauss-Seidel      0.0 | Two-Grid  0.00883 | AMG 4 levels  0.00808
# u737 | Analytical  0.00771 | Exact Inversion  0.00775 | Gauss-Seidel      0.0 | Two-Grid  0.00775 | AMG 4 levels  0.00707
# u738 | Analytical  0.00675 | Exact Inversion  0.00679 | Gauss-Seidel      0.0 | Two-Grid  0.00679 | AMG 4 levels  0.00618
# u739 | Analytical   0.0059 | Exact Inversion  0.00593 | Gauss-Seidel      0.0 | Two-Grid  0.00593 | AMG 4 levels  0.00538
# u740 | Analytical  0.00513 | Exact Inversion  0.00516 | Gauss-Seidel      0.0 | Two-Grid  0.00516 | AMG 4 levels  0.00467
# u741 | Analytical  0.00445 | Exact Inversion  0.00447 | Gauss-Seidel      0.0 | Two-Grid  0.00447 | AMG 4 levels  0.00404
# u742 | Analytical  0.00383 | Exact Inversion  0.00385 | Gauss-Seidel      0.0 | Two-Grid  0.00385 | AMG 4 levels  0.00347
# u743 | Analytical  0.00327 | Exact Inversion  0.00329 | Gauss-Seidel      0.0 | Two-Grid  0.00329 | AMG 4 levels  0.00296
# u744 | Analytical  0.00276 | Exact Inversion  0.00278 | Gauss-Seidel      0.0 | Two-Grid  0.00278 | AMG 4 levels  0.00249
# u745 | Analytical  0.00229 | Exact Inversion  0.00231 | Gauss-Seidel      0.0 | Two-Grid  0.00231 | AMG 4 levels  0.00207
# u746 | Analytical  0.00186 | Exact Inversion  0.00187 | Gauss-Seidel      0.0 | Two-Grid  0.00187 | AMG 4 levels  0.00168
# u747 | Analytical  0.00145 | Exact Inversion  0.00146 | Gauss-Seidel      0.0 | Two-Grid  0.00146 | AMG 4 levels  0.00131
# u748 | Analytical  0.00107 | Exact Inversion  0.00108 | Gauss-Seidel      0.0 | Two-Grid  0.00108 | AMG 4 levels  0.00096
# u749 | Analytical  0.00071 | Exact Inversion  0.00071 | Gauss-Seidel      0.0 | Two-Grid  0.00071 | AMG 4 levels  0.00063
# u750 | Analytical  0.00035 | Exact Inversion  0.00035 | Gauss-Seidel      0.0 | Two-Grid  0.00035 | AMG 4 levels  0.00031
# u81 | Analytical  0.73698 | Exact Inversion  0.73709 | Gauss-Seidel   0.6127 | Two-Grid  0.73693 | AMG 4 levels  0.73642
# u82 | Analytical  0.65155 | Exact Inversion  0.65175 | Gauss-Seidel  0.42829 | Two-Grid  0.65145 | AMG 4 levels  0.65044
# u83 | Analytical  0.57603 | Exact Inversion   0.5763 | Gauss-Seidel  0.28545 | Two-Grid  0.57588 | AMG 4 levels  0.57443
# u84 | Analytical  0.50926 | Exact Inversion  0.50957 | Gauss-Seidel  0.18196 | Two-Grid  0.50907 | AMG 4 levels  0.50722
# u85 | Analytical  0.45023 | Exact Inversion  0.45058 | Gauss-Seidel  0.11131 | Two-Grid  0.45002 | AMG 4 levels  0.44783
# u86 | Analytical  0.39804 | Exact Inversion  0.39841 | Gauss-Seidel  0.06557 | Two-Grid  0.39782 | AMG 4 levels  0.39534
# u87 | Analytical   0.3519 | Exact Inversion  0.35228 | Gauss-Seidel  0.03731 | Two-Grid  0.35169 | AMG 4 levels  0.34899
# u88 | Analytical  0.31111 | Exact Inversion  0.31149 | Gauss-Seidel  0.02056 | Two-Grid  0.31091 | AMG 4 levels  0.30804
# u89 | Analytical  0.27504 | Exact Inversion  0.27543 | Gauss-Seidel  0.01101 | Two-Grid  0.27488 | AMG 4 levels  0.27189
# u810 | Analytical  0.24316 | Exact Inversion  0.24354 | Gauss-Seidel  0.00574 | Two-Grid  0.24303 | AMG 4 levels  0.23996
# u811 | Analytical  0.21497 | Exact Inversion  0.21534 | Gauss-Seidel  0.00292 | Two-Grid  0.21489 | AMG 4 levels  0.21178
# u812 | Analytical  0.19005 | Exact Inversion  0.19041 | Gauss-Seidel  0.00145 | Two-Grid     0.19 | AMG 4 levels  0.18689
# u813 | Analytical  0.16802 | Exact Inversion  0.16836 | Gauss-Seidel   0.0007 | Two-Grid  0.16801 | AMG 4 levels  0.16493
# u814 | Analytical  0.14854 | Exact Inversion  0.14886 | Gauss-Seidel  0.00034 | Two-Grid  0.14857 | AMG 4 levels  0.14553
# u815 | Analytical  0.13132 | Exact Inversion  0.13162 | Gauss-Seidel  0.00016 | Two-Grid  0.13138 | AMG 4 levels  0.12842
# u816 | Analytical  0.11609 | Exact Inversion  0.11638 | Gauss-Seidel    7e-05 | Two-Grid  0.11618 | AMG 4 levels   0.1133
# u817 | Analytical  0.10263 | Exact Inversion   0.1029 | Gauss-Seidel    3e-05 | Two-Grid  0.10274 | AMG 4 levels  0.09996
# u818 | Analytical  0.09073 | Exact Inversion  0.09098 | Gauss-Seidel    1e-05 | Two-Grid  0.09085 | AMG 4 levels  0.08818
# u819 | Analytical  0.08021 | Exact Inversion  0.08044 | Gauss-Seidel    1e-05 | Two-Grid  0.08034 | AMG 4 levels  0.07778
# u820 | Analytical   0.0709 | Exact Inversion  0.07112 | Gauss-Seidel      0.0 | Two-Grid  0.07104 | AMG 4 levels   0.0686
# u821 | Analytical  0.06267 | Exact Inversion  0.06288 | Gauss-Seidel      0.0 | Two-Grid  0.06282 | AMG 4 levels   0.0605
# u822 | Analytical   0.0554 | Exact Inversion  0.05559 | Gauss-Seidel      0.0 | Two-Grid  0.05554 | AMG 4 levels  0.05334
# u823 | Analytical  0.04897 | Exact Inversion  0.04914 | Gauss-Seidel      0.0 | Two-Grid  0.04911 | AMG 4 levels  0.04702
# u824 | Analytical  0.04328 | Exact Inversion  0.04344 | Gauss-Seidel      0.0 | Two-Grid  0.04342 | AMG 4 levels  0.04144
# u825 | Analytical  0.03825 | Exact Inversion   0.0384 | Gauss-Seidel      0.0 | Two-Grid  0.03838 | AMG 4 levels  0.03652
# u826 | Analytical   0.0338 | Exact Inversion  0.03394 | Gauss-Seidel      0.0 | Two-Grid  0.03392 | AMG 4 levels  0.03217
# u827 | Analytical  0.02986 | Exact Inversion  0.02999 | Gauss-Seidel      0.0 | Two-Grid  0.02998 | AMG 4 levels  0.02834
# u828 | Analytical  0.02638 | Exact Inversion   0.0265 | Gauss-Seidel      0.0 | Two-Grid  0.02649 | AMG 4 levels  0.02495
# u829 | Analytical   0.0233 | Exact Inversion  0.02341 | Gauss-Seidel      0.0 | Two-Grid   0.0234 | AMG 4 levels  0.02196
# u830 | Analytical  0.02058 | Exact Inversion  0.02067 | Gauss-Seidel      0.0 | Two-Grid  0.02067 | AMG 4 levels  0.01933
# u831 | Analytical  0.01816 | Exact Inversion  0.01825 | Gauss-Seidel      0.0 | Two-Grid  0.01825 | AMG 4 levels    0.017
# u832 | Analytical  0.01602 | Exact Inversion   0.0161 | Gauss-Seidel      0.0 | Two-Grid   0.0161 | AMG 4 levels  0.01494
# u833 | Analytical  0.01413 | Exact Inversion   0.0142 | Gauss-Seidel      0.0 | Two-Grid   0.0142 | AMG 4 levels  0.01313
# u834 | Analytical  0.01245 | Exact Inversion  0.01251 | Gauss-Seidel      0.0 | Two-Grid  0.01251 | AMG 4 levels  0.01153
# u835 | Analytical  0.01096 | Exact Inversion  0.01102 | Gauss-Seidel      0.0 | Two-Grid  0.01102 | AMG 4 levels  0.01011
# u836 | Analytical  0.00964 | Exact Inversion  0.00969 | Gauss-Seidel      0.0 | Two-Grid  0.00969 | AMG 4 levels  0.00886
# u837 | Analytical  0.00846 | Exact Inversion  0.00851 | Gauss-Seidel      0.0 | Two-Grid  0.00851 | AMG 4 levels  0.00776
# u838 | Analytical  0.00741 | Exact Inversion  0.00745 | Gauss-Seidel      0.0 | Two-Grid  0.00745 | AMG 4 levels  0.00677
# u839 | Analytical  0.00647 | Exact Inversion  0.00651 | Gauss-Seidel      0.0 | Two-Grid  0.00651 | AMG 4 levels   0.0059
# u840 | Analytical  0.00563 | Exact Inversion  0.00567 | Gauss-Seidel      0.0 | Two-Grid  0.00567 | AMG 4 levels  0.00512
# u841 | Analytical  0.00488 | Exact Inversion  0.00491 | Gauss-Seidel      0.0 | Two-Grid  0.00491 | AMG 4 levels  0.00443
# u842 | Analytical   0.0042 | Exact Inversion  0.00423 | Gauss-Seidel      0.0 | Two-Grid  0.00423 | AMG 4 levels   0.0038
# u843 | Analytical  0.00359 | Exact Inversion  0.00361 | Gauss-Seidel      0.0 | Two-Grid  0.00361 | AMG 4 levels  0.00324
# u844 | Analytical  0.00303 | Exact Inversion  0.00305 | Gauss-Seidel      0.0 | Two-Grid  0.00305 | AMG 4 levels  0.00273
# ...
# u4821 | Analytical -0.02716 | Exact Inversion -0.02725 | Gauss-Seidel     -0.0 | Two-Grid -0.02722 | AMG 4 levels -0.02654
# u4822 | Analytical -0.02401 | Exact Inversion -0.02409 | Gauss-Seidel     -0.0 | Two-Grid -0.02407 | AMG 4 levels -0.02343
# u4823 | Analytical -0.02122 | Exact Inversion  -0.0213 | Gauss-Seidel     -0.0 | Two-Grid -0.02128 | AMG 4 levels -0.02069
# u4824 | Analytical -0.01876 | Exact Inversion -0.01883 | Gauss-Seidel     -0.0 | Two-Grid -0.01881 | AMG 4 levels -0.01826
# u4825 | Analytical -0.01658 | Exact Inversion -0.01664 | Gauss-Seidel     -0.0 | Two-Grid -0.01663 | AMG 4 levels -0.01611
# u4826 | Analytical -0.01465 | Exact Inversion -0.01471 | Gauss-Seidel     -0.0 | Two-Grid  -0.0147 | AMG 4 levels -0.01422
# u4827 | Analytical -0.01294 | Exact Inversion   -0.013 | Gauss-Seidel     -0.0 | Two-Grid -0.01299 | AMG 4 levels -0.01255
# u4828 | Analytical -0.01143 | Exact Inversion -0.01148 | Gauss-Seidel     -0.0 | Two-Grid -0.01148 | AMG 4 levels -0.01107
# u4829 | Analytical  -0.0101 | Exact Inversion -0.01014 | Gauss-Seidel     -0.0 | Two-Grid -0.01014 | AMG 4 levels -0.00977
# u4830 | Analytical -0.00892 | Exact Inversion -0.00896 | Gauss-Seidel     -0.0 | Two-Grid -0.00896 | AMG 4 levels -0.00862
# u4831 | Analytical -0.00787 | Exact Inversion -0.00791 | Gauss-Seidel     -0.0 | Two-Grid -0.00791 | AMG 4 levels  -0.0076
# u4832 | Analytical -0.00694 | Exact Inversion -0.00698 | Gauss-Seidel     -0.0 | Two-Grid -0.00698 | AMG 4 levels  -0.0067
# u4833 | Analytical -0.00612 | Exact Inversion -0.00615 | Gauss-Seidel     -0.0 | Two-Grid -0.00615 | AMG 4 levels  -0.0059
# u4834 | Analytical  -0.0054 | Exact Inversion -0.00542 | Gauss-Seidel     -0.0 | Two-Grid -0.00542 | AMG 4 levels  -0.0052
# u4835 | Analytical -0.00475 | Exact Inversion -0.00477 | Gauss-Seidel     -0.0 | Two-Grid -0.00477 | AMG 4 levels -0.00457
# u4836 | Analytical -0.00418 | Exact Inversion  -0.0042 | Gauss-Seidel     -0.0 | Two-Grid  -0.0042 | AMG 4 levels -0.00402
# u4837 | Analytical -0.00367 | Exact Inversion -0.00369 | Gauss-Seidel     -0.0 | Two-Grid -0.00369 | AMG 4 levels -0.00353
# u4838 | Analytical -0.00321 | Exact Inversion -0.00323 | Gauss-Seidel     -0.0 | Two-Grid -0.00323 | AMG 4 levels -0.00309
# u4839 | Analytical  -0.0028 | Exact Inversion -0.00282 | Gauss-Seidel     -0.0 | Two-Grid -0.00282 | AMG 4 levels -0.00269
# u4840 | Analytical -0.00244 | Exact Inversion -0.00246 | Gauss-Seidel     -0.0 | Two-Grid -0.00246 | AMG 4 levels -0.00234
# u4841 | Analytical -0.00212 | Exact Inversion -0.00213 | Gauss-Seidel     -0.0 | Two-Grid -0.00213 | AMG 4 levels -0.00203
# u4842 | Analytical -0.00182 | Exact Inversion -0.00183 | Gauss-Seidel     -0.0 | Two-Grid -0.00183 | AMG 4 levels -0.00175
# u4843 | Analytical -0.00156 | Exact Inversion -0.00157 | Gauss-Seidel     -0.0 | Two-Grid -0.00157 | AMG 4 levels -0.00149
# u4844 | Analytical -0.00131 | Exact Inversion -0.00132 | Gauss-Seidel     -0.0 | Two-Grid -0.00132 | AMG 4 levels -0.00126
# u4845 | Analytical -0.00109 | Exact Inversion  -0.0011 | Gauss-Seidel     -0.0 | Two-Grid  -0.0011 | AMG 4 levels -0.00104
# u4846 | Analytical -0.00088 | Exact Inversion -0.00089 | Gauss-Seidel     -0.0 | Two-Grid -0.00089 | AMG 4 levels -0.00085
# u4847 | Analytical -0.00069 | Exact Inversion  -0.0007 | Gauss-Seidel     -0.0 | Two-Grid  -0.0007 | AMG 4 levels -0.00066
# u4848 | Analytical -0.00051 | Exact Inversion -0.00051 | Gauss-Seidel     -0.0 | Two-Grid -0.00051 | AMG 4 levels -0.00049
# u4849 | Analytical -0.00034 | Exact Inversion -0.00034 | Gauss-Seidel     -0.0 | Two-Grid -0.00034 | AMG 4 levels -0.00032
# u4850 | Analytical -0.00017 | Exact Inversion -0.00017 | Gauss-Seidel     -0.0 | Two-Grid -0.00017 | AMG 4 levels -0.00016
# u491 | Analytical -0.21564 | Exact Inversion -0.21567 | Gauss-Seidel -0.18481 | Two-Grid -0.21564 | AMG 4 levels -0.21553
# u492 | Analytical -0.19064 | Exact Inversion  -0.1907 | Gauss-Seidel -0.13455 | Two-Grid -0.19064 | AMG 4 levels -0.19043
# u493 | Analytical -0.16855 | Exact Inversion -0.16863 | Gauss-Seidel -0.09425 | Two-Grid -0.16854 | AMG 4 levels -0.16823
# u494 | Analytical -0.14901 | Exact Inversion  -0.1491 | Gauss-Seidel -0.06363 | Two-Grid   -0.149 | AMG 4 levels  -0.1486
# u495 | Analytical -0.13174 | Exact Inversion -0.13184 | Gauss-Seidel -0.04149 | Two-Grid -0.13172 | AMG 4 levels -0.13125
# u496 | Analytical -0.11647 | Exact Inversion -0.11658 | Gauss-Seidel -0.02618 | Two-Grid -0.11645 | AMG 4 levels -0.11591
# u497 | Analytical -0.10297 | Exact Inversion -0.10308 | Gauss-Seidel -0.01603 | Two-Grid -0.10295 | AMG 4 levels -0.10236
# u498 | Analytical -0.09103 | Exact Inversion -0.09114 | Gauss-Seidel -0.00953 | Two-Grid -0.09102 | AMG 4 levels -0.09038
# u499 | Analytical -0.08048 | Exact Inversion -0.08059 | Gauss-Seidel -0.00552 | Two-Grid -0.08047 | AMG 4 levels  -0.0798
# u4910 | Analytical -0.07115 | Exact Inversion -0.07126 | Gauss-Seidel -0.00312 | Two-Grid -0.07115 | AMG 4 levels -0.07045
# u4911 | Analytical  -0.0629 | Exact Inversion -0.06301 | Gauss-Seidel -0.00172 | Two-Grid -0.06291 | AMG 4 levels  -0.0622
# u4912 | Analytical -0.05561 | Exact Inversion -0.05571 | Gauss-Seidel -0.00093 | Two-Grid -0.05562 | AMG 4 levels -0.05492
# u4913 | Analytical -0.04916 | Exact Inversion -0.04926 | Gauss-Seidel -0.00049 | Two-Grid -0.04918 | AMG 4 levels -0.04848
# u4914 | Analytical -0.04346 | Exact Inversion -0.04356 | Gauss-Seidel -0.00026 | Two-Grid -0.04349 | AMG 4 levels -0.04281
# u4915 | Analytical -0.03842 | Exact Inversion -0.03851 | Gauss-Seidel -0.00013 | Two-Grid -0.03845 | AMG 4 levels  -0.0378
# u4916 | Analytical -0.03397 | Exact Inversion -0.03405 | Gauss-Seidel   -7e-05 | Two-Grid   -0.034 | AMG 4 levels -0.03338
# u4917 | Analytical -0.03003 | Exact Inversion -0.03011 | Gauss-Seidel   -3e-05 | Two-Grid -0.03007 | AMG 4 levels -0.02947
# u4918 | Analytical -0.02655 | Exact Inversion -0.02662 | Gauss-Seidel   -2e-05 | Two-Grid -0.02659 | AMG 4 levels -0.02603
# u4919 | Analytical -0.02347 | Exact Inversion -0.02354 | Gauss-Seidel   -1e-05 | Two-Grid -0.02351 | AMG 4 levels -0.02299
# u4920 | Analytical -0.02075 | Exact Inversion -0.02081 | Gauss-Seidel     -0.0 | Two-Grid -0.02079 | AMG 4 levels  -0.0203
# u4921 | Analytical -0.01834 | Exact Inversion  -0.0184 | Gauss-Seidel     -0.0 | Two-Grid -0.01838 | AMG 4 levels -0.01792
# u4922 | Analytical -0.01621 | Exact Inversion -0.01627 | Gauss-Seidel     -0.0 | Two-Grid -0.01625 | AMG 4 levels -0.01582
# u4923 | Analytical -0.01433 | Exact Inversion -0.01438 | Gauss-Seidel     -0.0 | Two-Grid -0.01437 | AMG 4 levels -0.01397
# u4924 | Analytical -0.01266 | Exact Inversion -0.01271 | Gauss-Seidel     -0.0 | Two-Grid  -0.0127 | AMG 4 levels -0.01233
# u4925 | Analytical -0.01119 | Exact Inversion -0.01124 | Gauss-Seidel     -0.0 | Two-Grid -0.01123 | AMG 4 levels -0.01088
# u4926 | Analytical -0.00989 | Exact Inversion -0.00993 | Gauss-Seidel     -0.0 | Two-Grid -0.00993 | AMG 4 levels  -0.0096
# u4927 | Analytical -0.00874 | Exact Inversion -0.00877 | Gauss-Seidel     -0.0 | Two-Grid -0.00877 | AMG 4 levels -0.00847
# u4928 | Analytical -0.00772 | Exact Inversion -0.00775 | Gauss-Seidel     -0.0 | Two-Grid -0.00775 | AMG 4 levels -0.00747
# u4929 | Analytical -0.00682 | Exact Inversion -0.00685 | Gauss-Seidel     -0.0 | Two-Grid -0.00685 | AMG 4 levels -0.00659
# u4930 | Analytical -0.00602 | Exact Inversion -0.00605 | Gauss-Seidel     -0.0 | Two-Grid -0.00605 | AMG 4 levels -0.00582
# u4931 | Analytical -0.00531 | Exact Inversion -0.00534 | Gauss-Seidel     -0.0 | Two-Grid -0.00534 | AMG 4 levels -0.00513
# u4932 | Analytical -0.00469 | Exact Inversion -0.00471 | Gauss-Seidel     -0.0 | Two-Grid -0.00471 | AMG 4 levels -0.00452
# u4933 | Analytical -0.00413 | Exact Inversion -0.00416 | Gauss-Seidel     -0.0 | Two-Grid -0.00415 | AMG 4 levels -0.00399
# u4934 | Analytical -0.00364 | Exact Inversion -0.00366 | Gauss-Seidel     -0.0 | Two-Grid -0.00366 | AMG 4 levels -0.00351
# u4935 | Analytical -0.00321 | Exact Inversion -0.00322 | Gauss-Seidel     -0.0 | Two-Grid -0.00322 | AMG 4 levels -0.00309
# u4936 | Analytical -0.00282 | Exact Inversion -0.00283 | Gauss-Seidel     -0.0 | Two-Grid -0.00283 | AMG 4 levels -0.00271
# u4937 | Analytical -0.00247 | Exact Inversion -0.00249 | Gauss-Seidel     -0.0 | Two-Grid -0.00249 | AMG 4 levels -0.00238
# u4938 | Analytical -0.00217 | Exact Inversion -0.00218 | Gauss-Seidel     -0.0 | Two-Grid -0.00218 | AMG 4 levels -0.00208
# u4939 | Analytical -0.00189 | Exact Inversion -0.00191 | Gauss-Seidel     -0.0 | Two-Grid -0.00191 | AMG 4 levels -0.00182
# u4940 | Analytical -0.00165 | Exact Inversion -0.00166 | Gauss-Seidel     -0.0 | Two-Grid -0.00166 | AMG 4 levels -0.00158
# u4941 | Analytical -0.00143 | Exact Inversion -0.00144 | Gauss-Seidel     -0.0 | Two-Grid -0.00144 | AMG 4 levels -0.00137
# u4942 | Analytical -0.00123 | Exact Inversion -0.00124 | Gauss-Seidel     -0.0 | Two-Grid -0.00124 | AMG 4 levels -0.00118
# u4943 | Analytical -0.00105 | Exact Inversion -0.00106 | Gauss-Seidel     -0.0 | Two-Grid -0.00106 | AMG 4 levels -0.00101
# u4944 | Analytical -0.00089 | Exact Inversion -0.00089 | Gauss-Seidel     -0.0 | Two-Grid -0.00089 | AMG 4 levels -0.00085
# u4945 | Analytical -0.00074 | Exact Inversion -0.00074 | Gauss-Seidel     -0.0 | Two-Grid -0.00074 | AMG 4 levels  -0.0007
# u4946 | Analytical  -0.0006 | Exact Inversion  -0.0006 | Gauss-Seidel     -0.0 | Two-Grid  -0.0006 | AMG 4 levels -0.00057
# u4947 | Analytical -0.00047 | Exact Inversion -0.00047 | Gauss-Seidel     -0.0 | Two-Grid -0.00047 | AMG 4 levels -0.00045
# u4948 | Analytical -0.00034 | Exact Inversion -0.00035 | Gauss-Seidel     -0.0 | Two-Grid -0.00035 | AMG 4 levels -0.00033
# u4949 | Analytical -0.00023 | Exact Inversion -0.00023 | Gauss-Seidel     -0.0 | Two-Grid -0.00023 | AMG 4 levels -0.00022
# u4950 | Analytical -0.00011 | Exact Inversion -0.00011 | Gauss-Seidel     -0.0 | Two-Grid -0.00011 | AMG 4 levels -0.00011
# u501 | Analytical -0.10864 | Exact Inversion -0.10866 | Gauss-Seidel -0.09357 | Two-Grid -0.10864 | AMG 4 levels -0.10859
# u502 | Analytical -0.09605 | Exact Inversion -0.09608 | Gauss-Seidel -0.06856 | Two-Grid -0.09605 | AMG 4 levels -0.09594
# u503 | Analytical -0.08492 | Exact Inversion -0.08496 | Gauss-Seidel -0.04838 | Two-Grid -0.08491 | AMG 4 levels -0.08476
# u504 | Analytical -0.07507 | Exact Inversion -0.07512 | Gauss-Seidel -0.03294 | Two-Grid -0.07507 | AMG 4 levels -0.07487
# u505 | Analytical -0.06637 | Exact Inversion -0.06642 | Gauss-Seidel -0.02168 | Two-Grid -0.06637 | AMG 4 levels -0.06613
# u506 | Analytical -0.05868 | Exact Inversion -0.05873 | Gauss-Seidel -0.01381 | Two-Grid -0.05867 | AMG 4 levels  -0.0584
# u507 | Analytical -0.05188 | Exact Inversion -0.05193 | Gauss-Seidel -0.00854 | Two-Grid -0.05187 | AMG 4 levels -0.05157
# u508 | Analytical -0.04586 | Exact Inversion -0.04592 | Gauss-Seidel -0.00514 | Two-Grid -0.04586 | AMG 4 levels -0.04554
# u509 | Analytical -0.04055 | Exact Inversion  -0.0406 | Gauss-Seidel -0.00301 | Two-Grid -0.04054 | AMG 4 levels -0.04021
# u5010 | Analytical -0.03585 | Exact Inversion  -0.0359 | Gauss-Seidel -0.00172 | Two-Grid -0.03585 | AMG 4 levels  -0.0355
# u5011 | Analytical -0.03169 | Exact Inversion -0.03175 | Gauss-Seidel -0.00096 | Two-Grid -0.03169 | AMG 4 levels -0.03134
# u5012 | Analytical -0.02802 | Exact Inversion -0.02807 | Gauss-Seidel -0.00052 | Two-Grid -0.02802 | AMG 4 levels -0.02767
# u5013 | Analytical -0.02477 | Exact Inversion -0.02482 | Gauss-Seidel -0.00028 | Two-Grid -0.02478 | AMG 4 levels -0.02443
# u5014 | Analytical  -0.0219 | Exact Inversion -0.02195 | Gauss-Seidel -0.00015 | Two-Grid -0.02191 | AMG 4 levels -0.02157
# u5015 | Analytical -0.01936 | Exact Inversion  -0.0194 | Gauss-Seidel   -8e-05 | Two-Grid -0.01937 | AMG 4 levels -0.01905
# u5016 | Analytical -0.01711 | Exact Inversion -0.01716 | Gauss-Seidel   -4e-05 | Two-Grid -0.01713 | AMG 4 levels -0.01682
# u5017 | Analytical -0.01513 | Exact Inversion -0.01517 | Gauss-Seidel   -2e-05 | Two-Grid -0.01515 | AMG 4 levels -0.01485
# u5018 | Analytical -0.01338 | Exact Inversion -0.01341 | Gauss-Seidel   -1e-05 | Two-Grid  -0.0134 | AMG 4 levels -0.01312
# u5019 | Analytical -0.01182 | Exact Inversion -0.01186 | Gauss-Seidel     -0.0 | Two-Grid -0.01185 | AMG 4 levels -0.01158
# u5020 | Analytical -0.01045 | Exact Inversion -0.01048 | Gauss-Seidel     -0.0 | Two-Grid -0.01047 | AMG 4 levels -0.01023
# u5021 | Analytical -0.00924 | Exact Inversion -0.00927 | Gauss-Seidel     -0.0 | Two-Grid -0.00926 | AMG 4 levels -0.00903
# u5022 | Analytical -0.00817 | Exact Inversion -0.00819 | Gauss-Seidel     -0.0 | Two-Grid -0.00819 | AMG 4 levels -0.00797
# u5023 | Analytical -0.00722 | Exact Inversion -0.00724 | Gauss-Seidel     -0.0 | Two-Grid -0.00724 | AMG 4 levels -0.00704
# u5024 | Analytical -0.00638 | Exact Inversion  -0.0064 | Gauss-Seidel     -0.0 | Two-Grid  -0.0064 | AMG 4 levels -0.00621
# u5025 | Analytical -0.00564 | Exact Inversion -0.00566 | Gauss-Seidel     -0.0 | Two-Grid -0.00566 | AMG 4 levels -0.00548
# u5026 | Analytical -0.00498 | Exact Inversion   -0.005 | Gauss-Seidel     -0.0 | Two-Grid   -0.005 | AMG 4 levels -0.00484
# u5027 | Analytical  -0.0044 | Exact Inversion -0.00442 | Gauss-Seidel     -0.0 | Two-Grid -0.00442 | AMG 4 levels -0.00427
# u5028 | Analytical -0.00389 | Exact Inversion -0.00391 | Gauss-Seidel     -0.0 | Two-Grid -0.00391 | AMG 4 levels -0.00377
# u5029 | Analytical -0.00344 | Exact Inversion -0.00345 | Gauss-Seidel     -0.0 | Two-Grid -0.00345 | AMG 4 levels -0.00332
# u5030 | Analytical -0.00303 | Exact Inversion -0.00305 | Gauss-Seidel     -0.0 | Two-Grid -0.00305 | AMG 4 levels -0.00293
# u5031 | Analytical -0.00268 | Exact Inversion -0.00269 | Gauss-Seidel     -0.0 | Two-Grid -0.00269 | AMG 4 levels -0.00258
# u5032 | Analytical -0.00236 | Exact Inversion -0.00237 | Gauss-Seidel     -0.0 | Two-Grid -0.00237 | AMG 4 levels -0.00228
# u5033 | Analytical -0.00208 | Exact Inversion -0.00209 | Gauss-Seidel     -0.0 | Two-Grid -0.00209 | AMG 4 levels -0.00201
# u5034 | Analytical -0.00184 | Exact Inversion -0.00184 | Gauss-Seidel     -0.0 | Two-Grid -0.00184 | AMG 4 levels -0.00177
# u5035 | Analytical -0.00162 | Exact Inversion -0.00162 | Gauss-Seidel     -0.0 | Two-Grid -0.00162 | AMG 4 levels -0.00156
# u5036 | Analytical -0.00142 | Exact Inversion -0.00143 | Gauss-Seidel     -0.0 | Two-Grid -0.00143 | AMG 4 levels -0.00137
# u5037 | Analytical -0.00125 | Exact Inversion -0.00125 | Gauss-Seidel     -0.0 | Two-Grid -0.00125 | AMG 4 levels  -0.0012
# u5038 | Analytical -0.00109 | Exact Inversion  -0.0011 | Gauss-Seidel     -0.0 | Two-Grid  -0.0011 | AMG 4 levels -0.00105
# u5039 | Analytical -0.00095 | Exact Inversion -0.00096 | Gauss-Seidel     -0.0 | Two-Grid -0.00096 | AMG 4 levels -0.00092
# u5040 | Analytical -0.00083 | Exact Inversion -0.00084 | Gauss-Seidel     -0.0 | Two-Grid -0.00084 | AMG 4 levels  -0.0008
# u5041 | Analytical -0.00072 | Exact Inversion -0.00072 | Gauss-Seidel     -0.0 | Two-Grid -0.00072 | AMG 4 levels -0.00069
# u5042 | Analytical -0.00062 | Exact Inversion -0.00062 | Gauss-Seidel     -0.0 | Two-Grid -0.00062 | AMG 4 levels -0.00059
# u5043 | Analytical -0.00053 | Exact Inversion -0.00053 | Gauss-Seidel     -0.0 | Two-Grid -0.00053 | AMG 4 levels -0.00051
# u5044 | Analytical -0.00045 | Exact Inversion -0.00045 | Gauss-Seidel     -0.0 | Two-Grid -0.00045 | AMG 4 levels -0.00043
# u5045 | Analytical -0.00037 | Exact Inversion -0.00037 | Gauss-Seidel     -0.0 | Two-Grid -0.00037 | AMG 4 levels -0.00035
# u5046 | Analytical  -0.0003 | Exact Inversion  -0.0003 | Gauss-Seidel     -0.0 | Two-Grid  -0.0003 | AMG 4 levels -0.00029
# u5047 | Analytical -0.00024 | Exact Inversion -0.00024 | Gauss-Seidel     -0.0 | Two-Grid -0.00024 | AMG 4 levels -0.00022
# u5048 | Analytical -0.00017 | Exact Inversion -0.00017 | Gauss-Seidel     -0.0 | Two-Grid -0.00017 | AMG 4 levels -0.00017
# u5049 | Analytical -0.00011 | Exact Inversion -0.00012 | Gauss-Seidel     -0.0 | Two-Grid -0.00012 | AMG 4 levels -0.00011
# u5050 | Analytical   -6e-05 | Exact Inversion   -6e-05 | Gauss-Seidel     -0.0 | Two-Grid   -6e-05 | AMG 4 levels   -5e-05
