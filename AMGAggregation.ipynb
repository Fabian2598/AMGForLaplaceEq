# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import warnings
pi = np.pi

# %%
#Laplace matrix
def LaplaceMatrix(N):
    A = np.zeros((N*N,N*N))
    for i in range(N):
        for j in range(N):
            A[i+j*N,i+j*N] = -4 #Diagonal
    for i in range(N-1):
        for j in range(N):            
            A[i+j*N,i+j*N+1] = 1 #Upper diagonal of the triangular submatrices
            A[i+j*N+1,i+j*N] = 1 #Lower diagonal of the triangular submatrices        
    for i in range(N):
        for j in range(N-1):
            A[i+j*N  , i+j*N + N] = 1 #Identity upper matrix
            A[i+j*N + N , i+j*N ] = 1 #Identity lower matrix        
    A = -A #We do this to be consistent with Stueben notes
    return A

def BoundaryConditions(N):
    #Boundary conditions vector
    f = np.zeros(N*N)
    L, H, h = 1, 1, 1/(N+1) 
    x, y = np.zeros(N), np.zeros(N)
    for i in range(N):
        x[i], y[i] = (i+1)*h*L, (i+1)*h*L
    #Boundary at x = 0
    fx = np.zeros(N) #f_0j
    #Boundary at y = 0
    fy = np.sin(2*pi*x/L) #fj0
    #Boundary at y = H
    fH = np.zeros(N) #fj4
    #Boundary at x = L 
    fL = np.zeros(N) #f4j
    for i in range(N):
        f[i+(N-1)*i] = -fy[i] #Bottom boundary (y=0)
        f[i+(N-1)*i+ N-1 ] = -fH[i] #Top boundary (y=H)
    for i in range(N):
        f[i] += -fx[i] #Left boundary (x=0)
        f[i+N*(N-1)] += - fL[i] #Right boundary (x=L)
    f = -f #Consistency with Stueben notes
    return f
def AnalyticSolution(x,y):
    #Here x,y are numbers
    return np.sin(2*pi*x/L)*np.sinh(2*pi*(H-y)/L)/np.sinh(2*pi*H/L)

# %%
class TwoGrid_SA:
    #Two grid with smoothed aggregation
    def __init__(self,A,f,NVar,eps,w):
        self.f = f #Boundary conditions
        self.NVar = NVar #Dimension of the matrix A, equal to N*N
        self.A = A
        self.Si = [] #Strong couplings
        self.Cj = [] #Aggregates
        self.nl_1 = None #Number of aggregates
        self.eps = eps #Parameter used to create the strong coupling
        self.w = w #Parameter for the Jacobi step
        self.ProlOp = None #Interpolation operator
        self.CoarseOp = None #Coarsening operator
        self.GalerkinOp = None #Galerkin operator
        self.u = np.zeros(self.NVar) #Initial guess for the solution.
        
    def get_Matrix(self):
        return self.A
    def get_Si(self):
        return self.Si
    def get_ProlOp(self):
        return self.ProlOp
    
    def StrongCouplings(self):
    #Epsilon is used to define the strong couplings
        self.Si = []
        for i in range(self.NVar):
            B = set()
            for j in range(self.NVar):
                #This is done according to Vanek et. al Computing 56 (1996)
                if abs(self.A[i,j]) >= self.eps*np.sqrt(self.A[i,i]*self.A[j,j]):
                    B.add(j)
            self.Si.append(B)
    

    def Aggregates(self): 
        R = set()
        self.Cj = []
        for i in range(self.NVar):
            R.add(i)
        j = 0
        for i in range(self.NVar):
            if self.Si[i].issubset(R):
                self.Cj.append(self.Si[i])
                j = j+1
                R = R.difference(self.Si[i])
        #If there is any i left       
        if R != set():
            for i in R:
                Values = np.zeros(j)
                count, index = 0, 0
                for k in range(j):
                    if self.Si[i].intersection(self.Cj[k]) != set():
                        #If the intersection is empty, python returns set(), not {}
                        Values[k] = abs(self.A[i,k])/np.sqrt(self.A[i,i]*self.A[k,k])
                        count += 1
                        index = k
                if count > 1:
                    maximum=0
                    for k,value in enumerate(Values):
                        if value>maximum:
                            maximum=value
                            index=k
                if count != 0:
                    self.Cj[index] = self.Cj[index].union({i})
                    R = R.difference({i})
                    #print(self.Cj,i)
        #If there is still any i left. This is part is very unlikely to happen, it might even be impossible, but
        #the paper still mentions it. In case the code prints 'here', I'll have to check if this works correctly.
        if R != set():
            print('here')
            for i in R:
                self.Cj[j].append(R.intersection(self.Si[i]))
                j = j+1
                R = R.difference(self.Cj[j])
        self.nl_1 = len(self.Cj)

    
    def ConstructOperators(self):
        self.ProlOp = np.zeros((self.NVar,self.nl_1))
        if self.NVar == self.nl_1:
            return warnings.warn("Warning, the number of variables is equal to the number of aggregates")
            
        for i in range(self.NVar):
            for j in range(self.nl_1):
                if i in self.Cj[j]:
                    self.ProlOp[i,j] = 1 #Piecewise constant interpolator
        AF = np.zeros((self.NVar,self.NVar))
        Dinv = np.zeros((self.NVar,self.NVar))
        for i in range(self.NVar):
            for j in range(self.NVar):
                if j in self.Si[i] and i != j:
                    AF[i,j] = A[i,j]
        for i in range(self.NVar):
            sumA = 0
            for k in range(self.NVar):
                if k != i:
                    sumA += A[i,k] - AF[i,k]
            AF[i,i] = A[i,i] - sumA  
            Dinv = 1/AF[i,i]
        self.ProlOp = np.dot( np.identity(self.NVar) - self.w*np.dot(Dinv,AF), self.ProlOp )
        self.CoarseOp = np.transpose(self.ProlOp)
        self.GalerkinOp = np.dot(np.dot(self.CoarseOp,self.A),self.ProlOp) 
 
    def GaussSeidel(self,nu,initial_guess):
        #f has the boundary conditions
        #nu is the number of iterations        
        self.u = initial_guess
        for k in range(nu):
            for i in range(self.NVar):
                SumA = np.dot(self.A[i,i+1:],self.u[i+1:])
                SumB = np.dot(self.A[i,:i],self.u[:i]) 
                self.u[i] = (self.f[i] - SumA - SumB) / self.A[i,i]
        return self.u

    def ExactInversion(self):
        self.u = np.dot(np.linalg.inv(self.A),self.f)
        return self.u

    def set_up_phase(self):
        self.StrongCouplings() #Construct the strong couplings
        self.Aggregates() #Form the aggregates
        self.ConstructOperators() #Construct operators 

    def TwoGridMethod(self,nu1,nu2,initial_guess):
        #I have to call the set up phase when I call the function
        #nu1 --> pre-smoothing,  nu2 --> post-smoothing
        print('Number of aggregates',len(self.Cj))
        self.u = self.GaussSeidel(nu1,initial_guess) #Pre-smoothing
        errorC = np.dot(np.dot(np.linalg.inv(self.GalerkinOp),self.CoarseOp), self.f-np.dot(self.A,self.u) )
        self.u = self.u + np.dot(self.ProlOp,errorC) #Correction 
        self.u = self.GaussSeidel(nu2,self.u) #Post-smoothing
        return self.u

# %%
class AMG_SA:
    #AMG with smoothed aggregation
    def __init__(self,A,NVar,maxl,eps,w):
        self.NVar = NVar #Dimension of the matrix A, equal to N*N
        self.Al = [A]
        self.eps = eps #Parameter used to create the strong coupling
        self.w = w #Parameter for the Jacobi step
        self.ProlOpl = [] #Interpolation operator
        self.maxl = maxl

    def get_Al(self):
        return self.Al
    def get_ProlOpl(self):
        return self.ProlOpl

    def set_up_phase(self):
        for i in range(self.maxl):
            if i != maxl-1:
                Nl = self.Al[i].shape[0] #Number of variables at level l
                epsilon = self.eps*(0.5)**i #epsilon = epsilon0 * 0.5^l (based on Vanek's paper)
                print('eps at level l={0}: {1}'.format(i,epsilon))
                Syst_l = TwoGrid_SA(self.Al[i],np.zeros(Nl),Nl,epsilon,self.w) #I don't actually need the second argument, but
                #the way my program is written asks me for that thing to work.
                Syst_l.StrongCouplings() #Si at the l-level
                Syst_l.Aggregates() #Build the aggregates from l-level to l+1-level
                Syst_l.ConstructOperators() #Construct operators from l-level to l+1-level
                GalerkinOp = np.dot(
                    np.dot( np.transpose(Syst_l.get_ProlOp()), Syst_l.get_Matrix() ), 
                    Syst_l.get_ProlOp() ) 
                self.Al.append(GalerkinOp) #Store A at level l+1
                self.ProlOpl.append(Syst_l.get_ProlOp()) #Store the interpolation operator from l+1 -level to l-level 
    
    def GaussSeidel(self,nu,fl,ul,level):
        #nu is the number of iterations
        Nl = len(ul)
        for k in range(nu):
            for i in range(Nl):
                SumA = np.dot(self.Al[level][i,i+1:],ul[i+1:])
                SumB = np.dot(self.Al[level][i,:i],ul[:i]) 
                ul[i] = (fl[i] - SumA - SumB) / self.Al[level][i,i]
        return ul

    def V_cycle(self,nu1,nu2,l,fl,ul):
        """
        Multi-grid with V-Cycle and aggregation
        maxl is the finest level
        nu1: pre-smoothing
        nu2: post-smoothing
        We count l starting from zero
        """    
        print('Number of aggregates at level {0}: {1}'.format(l,self.Al[l].shape[0])) 
        if l == self.maxl - 1:
            return np.dot(np.linalg.inv(self.Al[l]),fl) #At this stage we only invert the matrix that's left  
        else:    
            ul = self.GaussSeidel(nu1,fl,ul,l) #Pre-smoothing. We don't want pre smoothing for the
            #exact solution
            fl_1 = np.dot( np.transpose(self.ProlOpl[l]),
                        fl-np.dot(self.Al[l],ul) ) #restriction
            ul_1 = np.zeros(self.Al[l+1].shape[0]) #Vector for the next level. 
            ul_1 = self.V_cycle(nu1,nu2,l+1,fl_1,ul_1)  
    
        ul = ul + np.dot(self.ProlOpl[l],ul_1) #Correction
        ul = self.GaussSeidel(nu2,fl,ul,l) #Pre-smoothing  #Post-smoothing
        return ul

# %%
N = 50
L, H, h = 1, 1, 1/(N+1) 
x, y = np.zeros(N), np.zeros(N)
for i in range(N):
    x[i], y[i] = (i+1)*h*L, (i+1)*h*L
A = LaplaceMatrix(N)
f = BoundaryConditions(N)
print('Number of variables on the grid',N*N)
# Out:
# Number of variables on the grid 2500

# %%
maxl, eps, w = 4, 0.08, 2/3 #We need a small epsilon to form more aggregates at coarser levels
AMG = AMG_SA(A,N*N,maxl,eps,w) 
AMG.set_up_phase()
# Out:
# eps at level l=0: 0.08
# eps at level l=1: 0.04
# eps at level l=2: 0.02

# %%
nu1, nu2, l = 5, 5, 0 #We start at l=0
u0 = np.zeros(N*N) #Initial guess
TIME = []
nmeas = 10
for i in range(nmeas):
    start = time.time()
    uAMG = AMG.V_cycle(nu1,nu2,l,f,u0) #We are not taking the set up phase into account
    end = time.time()
    TIME.append(end-start)
TIME = np.array(TIME)
print('Execution time',np.mean(TIME),'+-',np.std(TIME)/np.sqrt(nmeas),'seconds')
# Out:
# Number of aggregates at level 0: 2500
# Number of aggregates at level 1: 425
# Number of aggregates at level 2: 52
# Number of aggregates at level 3: 8
# Number of aggregates at level 0: 2500
# Number of aggregates at level 1: 425
# Number of aggregates at level 2: 52
# Number of aggregates at level 3: 8
# Number of aggregates at level 0: 2500
# Number of aggregates at level 1: 425
# Number of aggregates at level 2: 52
# Number of aggregates at level 3: 8
# Number of aggregates at level 0: 2500
# Number of aggregates at level 1: 425
# Number of aggregates at level 2: 52
# Number of aggregates at level 3: 8
# Number of aggregates at level 0: 2500
# Number of aggregates at level 1: 425
# Number of aggregates at level 2: 52
# Number of aggregates at level 3: 8
# Number of aggregates at level 0: 2500
# Number of aggregates at level 1: 425
# Number of aggregates at level 2: 52
# Number of aggregates at level 3: 8
# Number of aggregates at level 0: 2500
# Number of aggregates at level 1: 425
# Number of aggregates at level 2: 52
# Number of aggregates at level 3: 8
# Number of aggregates at level 0: 2500
# Number of aggregates at level 1: 425
# Number of aggregates at level 2: 52
# Number of aggregates at level 3: 8
# Number of aggregates at level 0: 2500
# Number of aggregates at level 1: 425
# Number of aggregates at level 2: 52
# Number of aggregates at level 3: 8
# Number of aggregates at level 0: 2500
# Number of aggregates at level 1: 425
# Number of aggregates at level 2: 52
# Number of aggregates at level 3: 8
# Execution time 0.10451850891113282 +- 0.0011354603387635684 seconds

# %%
eps, w = 0.2, 2/3
#The parameter epsilon is important. If it is too close to 1, it is possible to obtain a number
#of aggregates equal to the number of variables and then we will only invert the input matrix.
Sol = TwoGrid_SA(A,f,N*N,eps,w)
Sol.set_up_phase()

# %%
TIME = []
nmeas = 10
for i in range(nmeas):
    start = time.time()
    uFD = Sol.ExactInversion()
    end = time.time()
    TIME.append(end-start)
TIME = np.array(TIME)
print('Execution time',np.mean(TIME),'+-',np.std(TIME)/np.sqrt(nmeas),'seconds')
# Out:
# Execution time 0.19454576969146728 +- 0.0025653486035467203 seconds

# %%
u0 = np.zeros(N*N) #Initial guess
nu = 10
uGS = Sol.GaussSeidel(nu,u0)

# %%
nu1, nu2 = 5, 5
u0 = np.zeros(N*N)
TIME = []
nmeas = 10
for i in range(nmeas):
    start = time.time()
    uAMG_SA = Sol.TwoGridMethod(nu1,nu2,u0)
    end = time.time()
    TIME.append(end-start)
TIME = np.array(TIME)
print('Execution time',np.mean(TIME),'+-',np.std(TIME)/np.sqrt(nmeas),'seconds')
# Out:
# Number of aggregates 425
# Number of aggregates 425
# Number of aggregates 425
# Number of aggregates 425
# Number of aggregates 425
# Number of aggregates 425
# Number of aggregates 425
# Number of aggregates 425
# Number of aggregates 425
# Number of aggregates 425
# Execution time 0.09830305576324463 +- 0.0016522463855709333 seconds

# %%
for i in range(N):
    for j in range(N):
        string = 'u{:>0}{:>0} | Analytical {:>8} | Exact Inversion {:>8}'+\
              ' | Gauss-Seidel {:>8} | Two-Grid {:>8}' +\
              ' | AMG {:>0} levels {:>8}'
        print(string.format(i+1,j+1,
        np.round(AnalyticSolution(x[i],y[j]),5),
        np.round(uFD[i*N+j],5), 
        np.round(uGS[i*N+j],5),
        np.round(uAMG_SA[i*N+j],5),
        maxl, np.round(uAMG[i*N+j],5)
        ))
# Out:
# u11 | Analytical  0.10864 | Exact Inversion  0.10866 | Gauss-Seidel  0.08808 | Two-Grid  0.10839 | AMG 4 levels  0.10821
# u12 | Analytical  0.09605 | Exact Inversion  0.09608 | Gauss-Seidel  0.05951 | Two-Grid  0.09559 | AMG 4 levels  0.09523
# u13 | Analytical  0.08492 | Exact Inversion  0.08496 | Gauss-Seidel  0.03803 | Two-Grid   0.0842 | AMG 4 levels  0.08367
# u14 | Analytical  0.07507 | Exact Inversion  0.07512 | Gauss-Seidel  0.02309 | Two-Grid  0.07411 | AMG 4 levels  0.07341
# u15 | Analytical  0.06637 | Exact Inversion  0.06642 | Gauss-Seidel  0.01337 | Two-Grid  0.06525 | AMG 4 levels   0.0644
# u16 | Analytical  0.05868 | Exact Inversion  0.05873 | Gauss-Seidel  0.00742 | Two-Grid  0.05741 | AMG 4 levels  0.05641
# u17 | Analytical  0.05188 | Exact Inversion  0.05193 | Gauss-Seidel  0.00396 | Two-Grid  0.05048 | AMG 4 levels  0.04936
# u18 | Analytical  0.04586 | Exact Inversion  0.04592 | Gauss-Seidel  0.00204 | Two-Grid  0.04442 | AMG 4 levels  0.04319
# u19 | Analytical  0.04055 | Exact Inversion   0.0406 | Gauss-Seidel  0.00102 | Two-Grid  0.03909 | AMG 4 levels  0.03777
# u110 | Analytical  0.03585 | Exact Inversion   0.0359 | Gauss-Seidel  0.00049 | Two-Grid  0.03437 | AMG 4 levels  0.03299
# u111 | Analytical  0.03169 | Exact Inversion  0.03175 | Gauss-Seidel  0.00023 | Two-Grid  0.03026 | AMG 4 levels  0.02884
# u828 | Analytical  0.02638 | Exact Inversion   0.0265 | Gauss-Seidel      0.0 | Two-Grid  0.02454 | AMG 4 levels  0.02101
# u829 | Analytical   0.0233 | Exact Inversion  0.02341 | Gauss-Seidel      0.0 | Two-Grid  0.02172 | AMG 4 levels  0.01846
# u830 | Analytical  0.02058 | Exact Inversion  0.02067 | Gauss-Seidel      0.0 | Two-Grid  0.01922 | AMG 4 levels  0.01622
# u831 | Analytical  0.01816 | Exact Inversion  0.01825 | Gauss-Seidel      0.0 | Two-Grid    0.017 | AMG 4 levels  0.01425
# u832 | Analytical  0.01602 | Exact Inversion   0.0161 | Gauss-Seidel      0.0 | Two-Grid  0.01504 | AMG 4 levels   0.0125
# u833 | Analytical  0.01413 | Exact Inversion   0.0142 | Gauss-Seidel      0.0 | Two-Grid  0.01329 | AMG 4 levels  0.01096
# u834 | Analytical  0.01245 | Exact Inversion  0.01251 | Gauss-Seidel      0.0 | Two-Grid  0.01174 | AMG 4 levels  0.00959
# u835 | Analytical  0.01096 | Exact Inversion  0.01102 | Gauss-Seidel      0.0 | Two-Grid  0.01036 | AMG 4 levels  0.00839
# u836 | Analytical  0.00964 | Exact Inversion  0.00969 | Gauss-Seidel      0.0 | Two-Grid  0.00913 | AMG 4 levels  0.00732
# u837 | Analytical  0.00846 | Exact Inversion  0.00851 | Gauss-Seidel      0.0 | Two-Grid  0.00803 | AMG 4 levels  0.00638
# u838 | Analytical  0.00741 | Exact Inversion  0.00745 | Gauss-Seidel      0.0 | Two-Grid  0.00705 | AMG 4 levels  0.00554
# u839 | Analytical  0.00647 | Exact Inversion  0.00651 | Gauss-Seidel      0.0 | Two-Grid  0.00617 | AMG 4 levels   0.0048
# u840 | Analytical  0.00563 | Exact Inversion  0.00567 | Gauss-Seidel      0.0 | Two-Grid  0.00539 | AMG 4 levels  0.00414
# u841 | Analytical  0.00488 | Exact Inversion  0.00491 | Gauss-Seidel      0.0 | Two-Grid  0.00468 | AMG 4 levels  0.00356
# u842 | Analytical   0.0042 | Exact Inversion  0.00423 | Gauss-Seidel      0.0 | Two-Grid  0.00404 | AMG 4 levels  0.00304
# u843 | Analytical  0.00359 | Exact Inversion  0.00361 | Gauss-Seidel      0.0 | Two-Grid  0.00345 | AMG 4 levels  0.00258
# u844 | Analytical  0.00303 | Exact Inversion  0.00305 | Gauss-Seidel      0.0 | Two-Grid  0.00292 | AMG 4 levels  0.00216
# ...
# u4821 | Analytical -0.02716 | Exact Inversion -0.02725 | Gauss-Seidel     -0.0 | Two-Grid -0.02284 | AMG 4 levels -0.01981
# u4822 | Analytical -0.02401 | Exact Inversion -0.02409 | Gauss-Seidel     -0.0 | Two-Grid -0.02007 | AMG 4 levels -0.01716
# u4823 | Analytical -0.02122 | Exact Inversion  -0.0213 | Gauss-Seidel     -0.0 | Two-Grid -0.01766 | AMG 4 levels -0.01486
# u4824 | Analytical -0.01876 | Exact Inversion -0.01883 | Gauss-Seidel     -0.0 | Two-Grid -0.01554 | AMG 4 levels -0.01286
# u4825 | Analytical -0.01658 | Exact Inversion -0.01664 | Gauss-Seidel     -0.0 | Two-Grid -0.01367 | AMG 4 levels -0.01112
# u4826 | Analytical -0.01465 | Exact Inversion -0.01471 | Gauss-Seidel     -0.0 | Two-Grid -0.01204 | AMG 4 levels -0.00961
# u4827 | Analytical -0.01294 | Exact Inversion   -0.013 | Gauss-Seidel     -0.0 | Two-Grid  -0.0106 | AMG 4 levels  -0.0083
# u4828 | Analytical -0.01143 | Exact Inversion -0.01148 | Gauss-Seidel     -0.0 | Two-Grid -0.00933 | AMG 4 levels -0.00715
# u4829 | Analytical  -0.0101 | Exact Inversion -0.01014 | Gauss-Seidel     -0.0 | Two-Grid -0.00822 | AMG 4 levels -0.00616
# u4830 | Analytical -0.00892 | Exact Inversion -0.00896 | Gauss-Seidel     -0.0 | Two-Grid -0.00724 | AMG 4 levels  -0.0053
# u4831 | Analytical -0.00787 | Exact Inversion -0.00791 | Gauss-Seidel     -0.0 | Two-Grid -0.00637 | AMG 4 levels -0.00455
# u4832 | Analytical -0.00694 | Exact Inversion -0.00698 | Gauss-Seidel     -0.0 | Two-Grid  -0.0056 | AMG 4 levels  -0.0039
# u4833 | Analytical -0.00612 | Exact Inversion -0.00615 | Gauss-Seidel     -0.0 | Two-Grid -0.00493 | AMG 4 levels -0.00334
# u4834 | Analytical  -0.0054 | Exact Inversion -0.00542 | Gauss-Seidel     -0.0 | Two-Grid -0.00433 | AMG 4 levels -0.00285
# u4835 | Analytical -0.00475 | Exact Inversion -0.00477 | Gauss-Seidel     -0.0 | Two-Grid  -0.0038 | AMG 4 levels -0.00243
# u4836 | Analytical -0.00418 | Exact Inversion  -0.0042 | Gauss-Seidel     -0.0 | Two-Grid -0.00334 | AMG 4 levels -0.00206
# u4837 | Analytical -0.00367 | Exact Inversion -0.00369 | Gauss-Seidel     -0.0 | Two-Grid -0.00292 | AMG 4 levels -0.00175
# u4838 | Analytical -0.00321 | Exact Inversion -0.00323 | Gauss-Seidel     -0.0 | Two-Grid -0.00255 | AMG 4 levels -0.00148
# u4839 | Analytical  -0.0028 | Exact Inversion -0.00282 | Gauss-Seidel     -0.0 | Two-Grid -0.00223 | AMG 4 levels -0.00125
# u4840 | Analytical -0.00244 | Exact Inversion -0.00246 | Gauss-Seidel     -0.0 | Two-Grid -0.00193 | AMG 4 levels -0.00105
# u4841 | Analytical -0.00212 | Exact Inversion -0.00213 | Gauss-Seidel     -0.0 | Two-Grid -0.00167 | AMG 4 levels -0.00088
# u4842 | Analytical -0.00182 | Exact Inversion -0.00183 | Gauss-Seidel     -0.0 | Two-Grid -0.00144 | AMG 4 levels -0.00073
# u4843 | Analytical -0.00156 | Exact Inversion -0.00157 | Gauss-Seidel     -0.0 | Two-Grid -0.00123 | AMG 4 levels  -0.0006
# u4844 | Analytical -0.00131 | Exact Inversion -0.00132 | Gauss-Seidel     -0.0 | Two-Grid -0.00103 | AMG 4 levels  -0.0005
# u4845 | Analytical -0.00109 | Exact Inversion  -0.0011 | Gauss-Seidel     -0.0 | Two-Grid -0.00086 | AMG 4 levels  -0.0004
# u4846 | Analytical -0.00088 | Exact Inversion -0.00089 | Gauss-Seidel     -0.0 | Two-Grid  -0.0007 | AMG 4 levels -0.00032
# u4847 | Analytical -0.00069 | Exact Inversion  -0.0007 | Gauss-Seidel     -0.0 | Two-Grid -0.00055 | AMG 4 levels -0.00025
# u4848 | Analytical -0.00051 | Exact Inversion -0.00051 | Gauss-Seidel     -0.0 | Two-Grid  -0.0004 | AMG 4 levels -0.00018
# u4849 | Analytical -0.00034 | Exact Inversion -0.00034 | Gauss-Seidel     -0.0 | Two-Grid -0.00027 | AMG 4 levels -0.00012
# u4850 | Analytical -0.00017 | Exact Inversion -0.00017 | Gauss-Seidel     -0.0 | Two-Grid -0.00013 | AMG 4 levels   -6e-05
# u491 | Analytical -0.21564 | Exact Inversion -0.21567 | Gauss-Seidel -0.18481 | Two-Grid -0.21472 | AMG 4 levels -0.21443
# u492 | Analytical -0.19064 | Exact Inversion  -0.1907 | Gauss-Seidel -0.13455 | Two-Grid -0.18883 | AMG 4 levels -0.18827
# u493 | Analytical -0.16855 | Exact Inversion -0.16863 | Gauss-Seidel -0.09425 | Two-Grid  -0.1659 | AMG 4 levels -0.16507
# u494 | Analytical -0.14901 | Exact Inversion  -0.1491 | Gauss-Seidel -0.06363 | Two-Grid -0.14563 | AMG 4 levels -0.14456
# u495 | Analytical -0.13174 | Exact Inversion -0.13184 | Gauss-Seidel -0.04149 | Two-Grid -0.12774 | AMG 4 levels -0.12644
# u496 | Analytical -0.11647 | Exact Inversion -0.11658 | Gauss-Seidel -0.02618 | Two-Grid -0.11196 | AMG 4 levels -0.11045
# u497 | Analytical -0.10297 | Exact Inversion -0.10308 | Gauss-Seidel -0.01603 | Two-Grid -0.09808 | AMG 4 levels -0.09639
# u498 | Analytical -0.09103 | Exact Inversion -0.09114 | Gauss-Seidel -0.00953 | Two-Grid -0.08588 | AMG 4 levels -0.08404
# u499 | Analytical -0.08048 | Exact Inversion -0.08059 | Gauss-Seidel -0.00552 | Two-Grid -0.07517 | AMG 4 levels -0.07319
# u4910 | Analytical -0.07115 | Exact Inversion -0.07126 | Gauss-Seidel -0.00312 | Two-Grid -0.06579 | AMG 4 levels  -0.0637
# u4911 | Analytical  -0.0629 | Exact Inversion -0.06301 | Gauss-Seidel -0.00172 | Two-Grid -0.05758 | AMG 4 levels -0.05541
# u4912 | Analytical -0.05561 | Exact Inversion -0.05571 | Gauss-Seidel -0.00093 | Two-Grid -0.05039 | AMG 4 levels -0.04816
# u4913 | Analytical -0.04916 | Exact Inversion -0.04926 | Gauss-Seidel -0.00049 | Two-Grid -0.04411 | AMG 4 levels -0.04185
# u4914 | Analytical -0.04346 | Exact Inversion -0.04356 | Gauss-Seidel -0.00026 | Two-Grid -0.03864 | AMG 4 levels -0.03635
# u4915 | Analytical -0.03842 | Exact Inversion -0.03851 | Gauss-Seidel -0.00013 | Two-Grid -0.03385 | AMG 4 levels -0.03156
# u4916 | Analytical -0.03397 | Exact Inversion -0.03405 | Gauss-Seidel   -7e-05 | Two-Grid -0.02966 | AMG 4 levels -0.02739
# u4917 | Analytical -0.03003 | Exact Inversion -0.03011 | Gauss-Seidel   -3e-05 | Two-Grid -0.02602 | AMG 4 levels -0.02377
# u4918 | Analytical -0.02655 | Exact Inversion -0.02662 | Gauss-Seidel   -2e-05 | Two-Grid -0.02283 | AMG 4 levels -0.02062
# u4919 | Analytical -0.02347 | Exact Inversion -0.02354 | Gauss-Seidel   -1e-05 | Two-Grid -0.02004 | AMG 4 levels -0.01788
# u4920 | Analytical -0.02075 | Exact Inversion -0.02081 | Gauss-Seidel     -0.0 | Two-Grid  -0.0176 | AMG 4 levels -0.01551
# u4921 | Analytical -0.01834 | Exact Inversion  -0.0184 | Gauss-Seidel     -0.0 | Two-Grid -0.01547 | AMG 4 levels -0.01344
# u4922 | Analytical -0.01621 | Exact Inversion -0.01627 | Gauss-Seidel     -0.0 | Two-Grid  -0.0136 | AMG 4 levels -0.01164
# u4923 | Analytical -0.01433 | Exact Inversion -0.01438 | Gauss-Seidel     -0.0 | Two-Grid -0.01196 | AMG 4 levels -0.01009
# u4924 | Analytical -0.01266 | Exact Inversion -0.01271 | Gauss-Seidel     -0.0 | Two-Grid -0.01052 | AMG 4 levels -0.00873
# u4925 | Analytical -0.01119 | Exact Inversion -0.01124 | Gauss-Seidel     -0.0 | Two-Grid -0.00926 | AMG 4 levels -0.00755
# u4926 | Analytical -0.00989 | Exact Inversion -0.00993 | Gauss-Seidel     -0.0 | Two-Grid -0.00815 | AMG 4 levels -0.00652
# u4927 | Analytical -0.00874 | Exact Inversion -0.00877 | Gauss-Seidel     -0.0 | Two-Grid -0.00718 | AMG 4 levels -0.00563
# u4928 | Analytical -0.00772 | Exact Inversion -0.00775 | Gauss-Seidel     -0.0 | Two-Grid -0.00632 | AMG 4 levels -0.00486
# u4929 | Analytical -0.00682 | Exact Inversion -0.00685 | Gauss-Seidel     -0.0 | Two-Grid -0.00557 | AMG 4 levels -0.00418
# u4930 | Analytical -0.00602 | Exact Inversion -0.00605 | Gauss-Seidel     -0.0 | Two-Grid  -0.0049 | AMG 4 levels  -0.0036
# u4931 | Analytical -0.00531 | Exact Inversion -0.00534 | Gauss-Seidel     -0.0 | Two-Grid -0.00431 | AMG 4 levels -0.00309
# u4932 | Analytical -0.00469 | Exact Inversion -0.00471 | Gauss-Seidel     -0.0 | Two-Grid  -0.0038 | AMG 4 levels -0.00265
# u4933 | Analytical -0.00413 | Exact Inversion -0.00416 | Gauss-Seidel     -0.0 | Two-Grid -0.00334 | AMG 4 levels -0.00227
# u4934 | Analytical -0.00364 | Exact Inversion -0.00366 | Gauss-Seidel     -0.0 | Two-Grid -0.00293 | AMG 4 levels -0.00194
# u4935 | Analytical -0.00321 | Exact Inversion -0.00322 | Gauss-Seidel     -0.0 | Two-Grid -0.00258 | AMG 4 levels -0.00165
# u4936 | Analytical -0.00282 | Exact Inversion -0.00283 | Gauss-Seidel     -0.0 | Two-Grid -0.00226 | AMG 4 levels  -0.0014
# u4937 | Analytical -0.00247 | Exact Inversion -0.00249 | Gauss-Seidel     -0.0 | Two-Grid -0.00198 | AMG 4 levels -0.00119
# u4938 | Analytical -0.00217 | Exact Inversion -0.00218 | Gauss-Seidel     -0.0 | Two-Grid -0.00173 | AMG 4 levels -0.00101
# u4939 | Analytical -0.00189 | Exact Inversion -0.00191 | Gauss-Seidel     -0.0 | Two-Grid -0.00151 | AMG 4 levels -0.00085
# u4940 | Analytical -0.00165 | Exact Inversion -0.00166 | Gauss-Seidel     -0.0 | Two-Grid -0.00131 | AMG 4 levels -0.00071
# u4941 | Analytical -0.00143 | Exact Inversion -0.00144 | Gauss-Seidel     -0.0 | Two-Grid -0.00113 | AMG 4 levels  -0.0006
# u4942 | Analytical -0.00123 | Exact Inversion -0.00124 | Gauss-Seidel     -0.0 | Two-Grid -0.00097 | AMG 4 levels  -0.0005
# u4943 | Analytical -0.00105 | Exact Inversion -0.00106 | Gauss-Seidel     -0.0 | Two-Grid -0.00083 | AMG 4 levels -0.00041
# u4944 | Analytical -0.00089 | Exact Inversion -0.00089 | Gauss-Seidel     -0.0 | Two-Grid  -0.0007 | AMG 4 levels -0.00034
# u4945 | Analytical -0.00074 | Exact Inversion -0.00074 | Gauss-Seidel     -0.0 | Two-Grid -0.00058 | AMG 4 levels -0.00027
# u4946 | Analytical  -0.0006 | Exact Inversion  -0.0006 | Gauss-Seidel     -0.0 | Two-Grid -0.00047 | AMG 4 levels -0.00022
# u4947 | Analytical -0.00047 | Exact Inversion -0.00047 | Gauss-Seidel     -0.0 | Two-Grid -0.00037 | AMG 4 levels -0.00017
# u4948 | Analytical -0.00034 | Exact Inversion -0.00035 | Gauss-Seidel     -0.0 | Two-Grid -0.00027 | AMG 4 levels -0.00012
# u4949 | Analytical -0.00023 | Exact Inversion -0.00023 | Gauss-Seidel     -0.0 | Two-Grid -0.00018 | AMG 4 levels   -8e-05
# u4950 | Analytical -0.00011 | Exact Inversion -0.00011 | Gauss-Seidel     -0.0 | Two-Grid   -9e-05 | AMG 4 levels   -4e-05
# u501 | Analytical -0.10864 | Exact Inversion -0.10866 | Gauss-Seidel -0.09357 | Two-Grid  -0.1082 | AMG 4 levels -0.10805
# u502 | Analytical -0.09605 | Exact Inversion -0.09608 | Gauss-Seidel -0.06856 | Two-Grid -0.09516 | AMG 4 levels -0.09488
# u503 | Analytical -0.08492 | Exact Inversion -0.08496 | Gauss-Seidel -0.04838 | Two-Grid -0.08362 | AMG 4 levels -0.08321
# u504 | Analytical -0.07507 | Exact Inversion -0.07512 | Gauss-Seidel -0.03294 | Two-Grid -0.07342 | AMG 4 levels -0.07288
# u505 | Analytical -0.06637 | Exact Inversion -0.06642 | Gauss-Seidel -0.02168 | Two-Grid -0.06441 | AMG 4 levels -0.06376
# u506 | Analytical -0.05868 | Exact Inversion -0.05873 | Gauss-Seidel -0.01381 | Two-Grid -0.05646 | AMG 4 levels -0.05571
# u507 | Analytical -0.05188 | Exact Inversion -0.05193 | Gauss-Seidel -0.00854 | Two-Grid -0.04947 | AMG 4 levels -0.04863
# u508 | Analytical -0.04586 | Exact Inversion -0.04592 | Gauss-Seidel -0.00514 | Two-Grid -0.04333 | AMG 4 levels -0.04241
# u5030 | Analytical -0.00303 | Exact Inversion -0.00305 | Gauss-Seidel     -0.0 | Two-Grid -0.00247 | AMG 4 levels -0.00182
# u5031 | Analytical -0.00268 | Exact Inversion -0.00269 | Gauss-Seidel     -0.0 | Two-Grid -0.00218 | AMG 4 levels -0.00156
# u5032 | Analytical -0.00236 | Exact Inversion -0.00237 | Gauss-Seidel     -0.0 | Two-Grid -0.00192 | AMG 4 levels -0.00134
# u5033 | Analytical -0.00208 | Exact Inversion -0.00209 | Gauss-Seidel     -0.0 | Two-Grid -0.00169 | AMG 4 levels -0.00115
# u5034 | Analytical -0.00184 | Exact Inversion -0.00184 | Gauss-Seidel     -0.0 | Two-Grid -0.00148 | AMG 4 levels -0.00098
# u5035 | Analytical -0.00162 | Exact Inversion -0.00162 | Gauss-Seidel     -0.0 | Two-Grid  -0.0013 | AMG 4 levels -0.00084
# u5036 | Analytical -0.00142 | Exact Inversion -0.00143 | Gauss-Seidel     -0.0 | Two-Grid -0.00114 | AMG 4 levels -0.00071
# u5037 | Analytical -0.00125 | Exact Inversion -0.00125 | Gauss-Seidel     -0.0 | Two-Grid   -0.001 | AMG 4 levels  -0.0006
# u5038 | Analytical -0.00109 | Exact Inversion  -0.0011 | Gauss-Seidel     -0.0 | Two-Grid -0.00087 | AMG 4 levels -0.00051
# u5039 | Analytical -0.00095 | Exact Inversion -0.00096 | Gauss-Seidel     -0.0 | Two-Grid -0.00076 | AMG 4 levels -0.00043
# u5040 | Analytical -0.00083 | Exact Inversion -0.00084 | Gauss-Seidel     -0.0 | Two-Grid -0.00066 | AMG 4 levels -0.00036
# u5041 | Analytical -0.00072 | Exact Inversion -0.00072 | Gauss-Seidel     -0.0 | Two-Grid -0.00057 | AMG 4 levels  -0.0003
# u5042 | Analytical -0.00062 | Exact Inversion -0.00062 | Gauss-Seidel     -0.0 | Two-Grid -0.00049 | AMG 4 levels -0.00025
# u5043 | Analytical -0.00053 | Exact Inversion -0.00053 | Gauss-Seidel     -0.0 | Two-Grid -0.00042 | AMG 4 levels -0.00021
# u5044 | Analytical -0.00045 | Exact Inversion -0.00045 | Gauss-Seidel     -0.0 | Two-Grid -0.00035 | AMG 4 levels -0.00017
# u5045 | Analytical -0.00037 | Exact Inversion -0.00037 | Gauss-Seidel     -0.0 | Two-Grid -0.00029 | AMG 4 levels -0.00014
# u5046 | Analytical  -0.0003 | Exact Inversion  -0.0003 | Gauss-Seidel     -0.0 | Two-Grid -0.00024 | AMG 4 levels -0.00011
# u5047 | Analytical -0.00024 | Exact Inversion -0.00024 | Gauss-Seidel     -0.0 | Two-Grid -0.00019 | AMG 4 levels   -8e-05
# u5048 | Analytical -0.00017 | Exact Inversion -0.00017 | Gauss-Seidel     -0.0 | Two-Grid -0.00014 | AMG 4 levels   -6e-05
# u5049 | Analytical -0.00011 | Exact Inversion -0.00012 | Gauss-Seidel     -0.0 | Two-Grid   -9e-05 | AMG 4 levels   -4e-05
# u5050 | Analytical   -6e-05 | Exact Inversion   -6e-05 | Gauss-Seidel     -0.0 | Two-Grid   -5e-05 | AMG 4 levels   -2e-05
